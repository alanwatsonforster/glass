# %% [markdown]
# # Set Up

# %%
import sys
sys.path.append('/Users/alan/GitHub/glass/src/')
from glass import *

# %% [markdown]
# # Example

# %%
startgamesetup(None, sheets=[["F"]], variants=["use version 2.4 rules","use house rules"], style="temperate", dotsperhex=300, writelogfiles=False)
startgamesetup(None, sheets=[["F"]], variants=["use version 2.4 rules","use house rules"], style="arid", writelogfiles=False)

import glass.draw
import glass.hexcode


x = 8
y = 3
for c in [ "white", "natoblue", "natored", "natogreen", "natoyellow", "green", "lightgreen", "olivedrab", "tan", "lighttan", "sand", "lightsand", "khaki","airstrikegreen", "airstrikelightgreen", "airstriketan" ]:
    hexcode = "F-%02d%02d" % (x, y)
    setupgroundunit(c, hexcode, "infantry", color=c, identified=True)
    y += 1
    if y == 8:
        x += 1
        y = 3

x = 10
y = 9
hexcode = "F-%02d%02d" % (x, y)
setupgroundunit("1/1", hexcode, "infantry", stack="1/1", color="lightgreen", identified=True)
y += 1
hexcode = "F-%02d%02d" % (x, y)
setupgroundunit("1/2", hexcode, "infantry", stack="1/2", color="lightgreen", identified=True)
setupgroundunit("2/2", hexcode, "infantry", stack="2/2", color="lightgreen", identified=True)
x += 1
y -= 1
hexcode = "F-%02d%02d" % (x, y)
setupgroundunit("1/3", hexcode, "infantry", stack="1/3", color="lightgreen", identified=True)
setupgroundunit("2/3", hexcode, "infantry", stack="2/3", color="lightgreen", identified=True)
setupgroundunit("3/3", hexcode, "infantry", stack="3/3", color="lightgreen", identified=True)
y += 1
hexcode = "F-%02d%02d" % (x, y)
setupgroundunit("1/4", hexcode, "infantry", stack="1/4", color="lightgreen", identified=True)
setupgroundunit("2/4", hexcode, "infantry", stack="2/4", color="lightgreen", identified=True)
setupgroundunit("3/4", hexcode, "infantry", stack="3/4", color="lightgreen", identified=True)
setupgroundunit("4/4", hexcode, "infantry", stack="4/4", color="lightgreen", identified=True)



x = 8
y = 9
hexcode = "F-%02d%02d" % (x, y)
setupgroundunit("entrenched", hexcode, "infantry", stack="1/1", color="lightgreen", identified=True, protectionclass="entrenched")
y += 1
hexcode = "F-%02d%02d" % (x, y)
setupgroundunit("bunkered", hexcode, "infantry", stack="1/1", color="lightgreen", identified=True, protectionclass="bunkered")


x = 13
y = 3
for s in [ 
    "infantry platoon",
    "infantry HQ platoon",
    "medium tank platoon",
    "truck platoon",
    "mobile EWR-A",
    "mobile FCR-A",
    "mobile CCU platoon",
    "SA-2B battery", "SA-2C battery", "SA-2E battery", "SA-2F battery",
    "KS-12 battery", "KS-19 battery", "S-60 battery", "M-38 battery", "ZPU-4 battery", "mobile ZPU-4 section", "ZPU-2 battery", "ZPU-1 battery", "ZU-23 battery", "mobile ZU-23 section", "ZSU-57-2 section", "ZSU-23-4 section", "Tunguska section", "Pantsir S1 section", "Pantsir S1M section", 
    "M55 battery", "mobile M55 section", "M16 section", "M42 section",
    ]:
    hexcode = "F-%02d%02d" % (x, y)
    if s.startswith("KS"):
        azimuth = "ENE"
    else:
        azimuth = None
    name = s.replace(" ", "\n ")
    setupgroundunit(name + " ", hexcode, s, azimuth=azimuth, color="lightgreen", identified=True)
    y += 1
    if y == 12:
        x += 1
        y = 3

endgamesetup()
drawmap(zoom=False, xmin=2, xmax=18, ymin=13, ymax=23.5)
#drawmap(zoom=False, xmin=2, xmax=16, ymin=13, ymax=23.5, compactstacks=False)
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['F']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 300.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['F']].
# set-up      : north is up.
# set-up      : map option style is 'arid'.
#
# set-up      :       :       : creating ground unit white.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit natoblue.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit natored.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit natogreen.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit natoyellow.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit green.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit lightgreen.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit olivedrab.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit tan.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit lighttan.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit sand.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit lightsand.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit khaki.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit airstrikegreen.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit airstrikelightgreen.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit airstriketan.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 1/1.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 1/2.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 2/2.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 1/3.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 2/3.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 3/3.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 1/4.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 2/4.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 3/4.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 4/4.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit entrenched.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit bunkered.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit infantry
#  platoon .
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit infantry
#  HQ
#  platoon .
# set-up      :       :       : type is infantry HQ platoon.
#
# set-up      :       :       : creating ground unit medium
#  tank
#  platoon .
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit truck
#  platoon .
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit mobile
#  EWR-A .
# set-up      :       :       : type is mobile EWR-A.
#
# set-up      :       :       : creating ground unit mobile
#  FCR-A .
# set-up      :       :       : type is mobile FCR-A.
#
# set-up      :       :       : creating ground unit mobile
#  CCU
#  platoon .
# set-up      :       :       : type is mobile CCU platoon.
#
# set-up      :       :       : creating ground unit SA-2B
#  battery .
# set-up      :       :       : type is SA-2B battery.
#
# set-up      :       :       : creating ground unit SA-2C
#  battery .
# set-up      :       :       : type is SA-2C battery.
#
# set-up      :       :       : creating ground unit SA-2E
#  battery .
# set-up      :       :       : type is SA-2E battery.
#
# set-up      :       :       : creating ground unit SA-2F
#  battery .
# set-up      :       :       : type is SA-2F battery.
#
# set-up      :       :       : creating ground unit KS-12
#  battery .
# set-up      :       :       : type is KS-12 battery.
#
# set-up      :       :       : creating ground unit KS-19
#  battery .
# set-up      :       :       : type is KS-19 battery.
#
# set-up      :       :       : creating ground unit S-60
#  battery .
# set-up      :       :       : type is S-60 battery.
#
# set-up      :       :       : creating ground unit M-38
#  battery .
# set-up      :       :       : type is M-38 battery.
#
# set-up      :       :       : creating ground unit ZPU-4
#  battery .
# set-up      :       :       : type is ZPU-4 battery.
#
# set-up      :       :       : creating ground unit mobile
#  ZPU-4
#  section .
# set-up      :       :       : type is mobile ZPU-4 section.
#
# set-up      :       :       : creating ground unit ZPU-2
#  battery .
# set-up      :       :       : type is ZPU-2 battery.
#
# set-up      :       :       : creating ground unit ZPU-1
#  battery .
# set-up      :       :       : type is ZPU-1 battery.
#
# set-up      :       :       : creating ground unit ZU-23
#  battery .
# set-up      :       :       : type is ZU-23 battery.
#
# set-up      :       :       : creating ground unit mobile
#  ZU-23
#  section .
# set-up      :       :       : type is mobile ZU-23 section.
#
# set-up      :       :       : creating ground unit ZSU-57-2
#  section .
# set-up      :       :       : type is ZSU-57-2 section.
#
# set-up      :       :       : creating ground unit ZSU-23-4
#  section .
# set-up      :       :       : type is ZSU-23-4 section.
#
# set-up      :       :       : creating ground unit Tunguska
#  section .
# set-up      :       :       : type is Tunguska section.
#
# set-up      :       :       : creating ground unit Pantsir
#  S1
#  section .
# set-up      :       :       : type is Pantsir S1 section.
#
# set-up      :       :       : creating ground unit Pantsir
#  S1M
#  section .
# set-up      :       :       : type is Pantsir S1M section.
#
# set-up      :       :       : creating ground unit M55
#  battery .
# set-up      :       :       : type is M55 battery.
#
# set-up      :       :       : creating ground unit mobile
#  M55
#  section .
# set-up      :       :       : type is mobile M55 section.
#
# set-up      :       :       : creating ground unit M16
#  section .
# set-up      :       :       : type is M16 section.
#
# set-up      :       :       : creating ground unit M42
#  section .
# set-up      :       :       : type is M42 section.
#
# set-up      : end of game set-up.
