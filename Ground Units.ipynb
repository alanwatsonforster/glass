# %% [markdown]
# # Set Up

# %%
import sys
sys.path.append('/Users/alan/GitHub/glass/src/')
from glass import *

# %% [markdown]
# # Example

# %%
startgamesetup(None, sheets=[["F"]], variants=["use version 2.4 rules","use house rules"], style="temperate", dotsperhex=300, writelogfiles=False)
startgamesetup(None, sheets=[["F"]], variants=["use version 2.4 rules","use house rules"], style="temperate", writelogfiles=False)

x = 3
y = 3
for s in [
    "infantry", "armor", "artillery", "reconnaissance", "antiarmor", "airdefense", "supply", "transportation", "ammunition", "fuel", "ordnance",
    "headquarters", "missile", "gun", "multiplerocket", "radar", "motorized", "wheeled", "limitedwheeled",
    "locomotive", "railcar", "truck", "barge", "junk", "building", "tower", "hangar", "fixedwing", "rotarywing"
    ]:
    hexcode = "F-%02d%02d" % (x, y)
    setupgroundunit(s, hexcode, symbols=s, color="lightgreen")
    y += 1
    if y == 12:
        x += 1
        y = 3

x = 9
y = 3
for c in [ "white", "natoblue", "natored", "natogreen", "natoyellow", "green", "lightgreen", "tan", "darktan", "sand" ]:
    hexcode = "F-%02d%02d" % (x, y)
    setupgroundunit(c, hexcode, "infantry", color=c)
    y += 1
    if y == 8:
        x += 1
        y = 3

x = 9
y = 9
hexcode = "F-%02d%02d" % (x, y)
setupgroundunit("1/1", hexcode, "infantry", stack="1/1", color="lightgreen")
y += 1
hexcode = "F-%02d%02d" % (x, y)
setupgroundunit("1/2", hexcode, "infantry", stack="1/2", color="lightgreen")
setupgroundunit("2/2", hexcode, "infantry", stack="2/2", color="lightgreen")
x += 1
y -= 1
hexcode = "F-%02d%02d" % (x, y)
setupgroundunit("1/3", hexcode, "infantry", stack="1/3", color="lightgreen")
setupgroundunit("2/3", hexcode, "infantry", stack="2/3", color="lightgreen")
setupgroundunit("3/3", hexcode, "infantry", stack="3/3", color="lightgreen")
y += 1
hexcode = "F-%02d%02d" % (x, y)
setupgroundunit("1/4", hexcode, "infantry", stack="1/4", color="lightgreen")
setupgroundunit("2/4", hexcode, "infantry", stack="2/4", color="lightgreen")
setupgroundunit("3/4", hexcode, "infantry", stack="3/4", color="lightgreen")
setupgroundunit("4/4", hexcode, "infantry", stack="4/4", color="lightgreen")


x = 12
y = 3
for s in [ 
    "infantry",
    "infantryheadquarters",
    "mediumtank",
    "truck",
    "EWR-A",
    "FCR-A",
    "airdefenseheadquarters",
    "SA-2B", "SA-2C", "SA-2E", "SA-2F",
    "KS-12", "KS-19", "S-60", "M-38", "ZPU-4", "truck-mounted ZPU-4", "ZPU-2", "ZPU-1", "ZU-23", "truck-mounted ZU-23", "ZSU-57-2", "ZSU-23-4", "Tunguska", "Pantsir", 
    "M55", "truck-mounted M55", "M16", "M42",
    ]:
    hexcode = "F-%02d%02d" % (x, y)
    if s.startswith("KS"):
        azimuth = "ENE"
    else:
        azimuth = None
    setupgroundunit(s + " ", hexcode, s, azimuth=azimuth, color="lightgreen")
    y += 1
    if y == 12:
        x += 1
        y = 3

endgamesetup()
drawmap(zoom=False, xmin=2, xmax=16, ymin=13, ymax=23.5)
#drawmap(zoom=False, xmin=2, xmax=16, ymin=13, ymax=23.5, compactstacks=False)
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['F']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 300.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['F']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
#
# set-up      :       :       : creating ground unit infantry.
#
# set-up      :       :       : creating ground unit armor.
#
# set-up      :       :       : creating ground unit artillery.
#
# set-up      :       :       : creating ground unit reconnaissance.
#
# set-up      :       :       : creating ground unit antiarmor.
#
# set-up      :       :       : creating ground unit airdefense.
#
# set-up      :       :       : creating ground unit supply.
#
# set-up      :       :       : creating ground unit transportation.
#
# set-up      :       :       : creating ground unit ammunition.
#
# set-up      :       :       : creating ground unit fuel.
#
# set-up      :       :       : creating ground unit ordnance.
#
# set-up      :       :       : creating ground unit headquarters.
#
# set-up      :       :       : creating ground unit missile.
#
# set-up      :       :       : creating ground unit gun.
#
# set-up      :       :       : creating ground unit multiplerocket.
#
# set-up      :       :       : creating ground unit radar.
#
# set-up      :       :       : creating ground unit motorized.
#
# set-up      :       :       : creating ground unit wheeled.
#
# set-up      :       :       : creating ground unit limitedwheeled.
#
# set-up      :       :       : creating ground unit locomotive.
#
# set-up      :       :       : creating ground unit railcar.
#
# set-up      :       :       : creating ground unit truck.
#
# set-up      :       :       : creating ground unit barge.
#
# set-up      :       :       : creating ground unit junk.
#
# set-up      :       :       : creating ground unit building.
#
# set-up      :       :       : creating ground unit tower.
#
# set-up      :       :       : creating ground unit hangar.
#
# set-up      :       :       : creating ground unit fixedwing.
#
# set-up      :       :       : creating ground unit rotarywing.
#
# set-up      :       :       : creating ground unit white.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit natoblue.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit natored.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit natogreen.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit natoyellow.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit green.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit lightgreen.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit tan.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit darktan.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit sand.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 1/1.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 1/2.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 2/2.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 1/3.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 2/3.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 3/3.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 1/4.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 2/4.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 3/4.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit 4/4.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit infantry .
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit infantryheadquarters .
# set-up      :       :       : type is infantryheadquarters.
#
# set-up      :       :       : creating ground unit mediumtank .
# set-up      :       :       : type is mediumtank.
#
# set-up      :       :       : creating ground unit truck .
# set-up      :       :       : type is truck.
#
# set-up      :       :       : creating ground unit EWR-A .
# set-up      :       :       : type is EWR-A.
#
# set-up      :       :       : creating ground unit FCR-A .
# set-up      :       :       : type is FCR-A.
#
# set-up      :       :       : creating ground unit airdefenseheadquarters .
# set-up      :       :       : type is airdefenseheadquarters.
#
# set-up      :       :       : creating ground unit SA-2B .
# set-up      :       :       : type is SA-2B.
#
# set-up      :       :       : creating ground unit SA-2C .
# set-up      :       :       : type is SA-2C.
#
# set-up      :       :       : creating ground unit SA-2E .
# set-up      :       :       : type is SA-2E.
#
# set-up      :       :       : creating ground unit SA-2F .
# set-up      :       :       : type is SA-2F.
#
# set-up      :       :       : creating ground unit KS-12 .
# set-up      :       :       : type is KS-12.
#
# set-up      :       :       : creating ground unit KS-19 .
# set-up      :       :       : type is KS-19.
#
# set-up      :       :       : creating ground unit S-60 .
# set-up      :       :       : type is S-60.
#
# set-up      :       :       : creating ground unit M-38 .
# set-up      :       :       : type is M-38.
#
# set-up      :       :       : creating ground unit ZPU-4 .
# set-up      :       :       : type is ZPU-4.
#
# set-up      :       :       : creating ground unit truck-mounted ZPU-4 .
# set-up      :       :       : type is truck-mounted ZPU-4.
#
# set-up      :       :       : creating ground unit ZPU-2 .
# set-up      :       :       : type is ZPU-2.
#
# set-up      :       :       : creating ground unit ZPU-1 .
# set-up      :       :       : type is ZPU-1.
#
# set-up      :       :       : creating ground unit ZU-23 .
# set-up      :       :       : type is ZU-23.
#
# set-up      :       :       : creating ground unit truck-mounted ZU-23 .
# set-up      :       :       : type is truck-mounted ZU-23.
#
# set-up      :       :       : creating ground unit ZSU-57-2 .
# set-up      :       :       : type is ZSU-57-2.
#
# set-up      :       :       : creating ground unit ZSU-23-4 .
# set-up      :       :       : type is ZSU-23-4.
#
# set-up      :       :       : creating ground unit Tunguska .
# set-up      :       :       : type is Tunguska.
#
# set-up      :       :       : creating ground unit Pantsir .
# set-up      :       :       : type is Pantsir.
#
# set-up      :       :       : creating ground unit M55 .
# set-up      :       :       : type is M55.
#
# set-up      :       :       : creating ground unit truck-mounted M55 .
# set-up      :       :       : type is truck-mounted M55.
#
# set-up      :       :       : creating ground unit M16 .
# set-up      :       :       : type is M16.
#
# set-up      :       :       : creating ground unit M42 .
# set-up      :       :       : type is M42.
#
# set-up      : end of game set-up.
