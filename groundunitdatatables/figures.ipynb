# %%
import sys
print(sys.path)
# Out:
# ['/Users/alan/GitHub/Home/glass/src', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python313.zip', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python3.13', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python3.13/lib-dynload', '', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python3.13/site-packages']

# %%
from glass import *

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [

        "infantry platoon",
        "infantry HQ platoon",
        "infantry FAC section",
        "",
        "",
        "",

        "heavy tank platoon",
        "medium tank platoon",
        "light tank platoon",
        "heavy tank HQ platoon",
        "medium tank HQ platoon",
        "light tank HQ platoon",

        "medium IFV platoon",
        "light IFV platoon",
        "heavy APC platoon",
        "medium APC platoon",
        "light APC platoon",
        "",


        "truck platoon",
        "light truck platoon",
        "light truck section",
        "light truck squad",
        "",
        "",

        "towed artillery battery",
        "armored artillery battery",
        "mobile artillery battery",
        "armored rocket artillery battery",
        "mobile rocket artillery battery",
        "mobile missile artillery battery",

    ]:
        if s != "":
            if s.startswith("KS"):
                azimuth = "ENE"
            else:
                azimuth = None
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = s.replace(" ", "\n  ")
            setupgroundunit(name, hexcode, s, azimuth=azimuth, color="lightgreen", counter=counter, identified=True)
        if y == 8:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False,xmin=1.5,xmax=12.5,ymin=16.5,ymax=23.5)
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit infantry
#   platoon.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit infantry
#   HQ
#   platoon.
# set-up      :       :       : type is infantry HQ platoon.
#
# set-up      :       :       : creating ground unit infantry
#   FAC
#   section.
# set-up      :       :       : type is infantry FAC section.
#
# set-up      :       :       : creating ground unit heavy
#   tank
#   platoon.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit medium
#   tank
#   platoon.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit light
#   tank
#   platoon.
# set-up      :       :       : type is light tank platoon.
#
# set-up      :       :       : creating ground unit heavy
#   tank
#   HQ
#   platoon.
# set-up      :       :       : type is heavy tank HQ platoon.
#
# set-up      :       :       : creating ground unit medium
#   tank
#   HQ
#   platoon.
# set-up      :       :       : type is medium tank HQ platoon.
#
# set-up      :       :       : creating ground unit light
#   tank
#   HQ
#   platoon.
# set-up      :       :       : type is light tank HQ platoon.
#
# set-up      :       :       : creating ground unit medium
#   IFV
#   platoon.
# set-up      :       :       : type is medium IFV platoon.
#
# set-up      :       :       : creating ground unit light
#   IFV
#   platoon.
# set-up      :       :       : type is light IFV platoon.
#
# set-up      :       :       : creating ground unit heavy
#   APC
#   platoon.
# set-up      :       :       : type is heavy APC platoon.
#
# set-up      :       :       : creating ground unit medium
#   APC
#   platoon.
# set-up      :       :       : type is medium APC platoon.
#
# set-up      :       :       : creating ground unit light
#   APC
#   platoon.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit truck
#   platoon.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit light
#   truck
#   platoon.
# set-up      :       :       : type is light truck platoon.
#
# set-up      :       :       : creating ground unit light
#   truck
#   section.
# set-up      :       :       : type is light truck section.
#
# set-up      :       :       : creating ground unit light
#   truck
#   squad.
# set-up      :       :       : type is light truck squad.
#
# set-up      :       :       : creating ground unit towed
#   artillery
#   battery.
# set-up      :       :       : type is towed artillery battery.
#
# set-up      :       :       : creating ground unit armored
#   artillery
#   battery.
# set-up      :       :       : type is armored artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   artillery
#   battery.
# set-up      :       :       : type is mobile artillery battery.
#
# set-up      :       :       : creating ground unit armored
#   rocket
#   artillery
#   battery.
# set-up      :       :       : type is armored rocket artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   rocket
#   artillery
#   battery.
# set-up      :       :       : type is mobile rocket artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   missile
#   artillery
#   battery.
# set-up      :       :       : type is mobile missile artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit infantry
#   platoon.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit infantry
#   HQ
#   platoon.
# set-up      :       :       : type is infantry HQ platoon.
#
# set-up      :       :       : creating ground unit infantry
#   FAC
#   section.
# set-up      :       :       : type is infantry FAC section.
#
# set-up      :       :       : creating ground unit heavy
#   tank
#   platoon.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit medium
#   tank
#   platoon.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit light
#   tank
#   platoon.
# set-up      :       :       : type is light tank platoon.
#
# set-up      :       :       : creating ground unit heavy
#   tank
#   HQ
#   platoon.
# set-up      :       :       : type is heavy tank HQ platoon.
#
# set-up      :       :       : creating ground unit medium
#   tank
#   HQ
#   platoon.
# set-up      :       :       : type is medium tank HQ platoon.
#
# set-up      :       :       : creating ground unit light
#   tank
#   HQ
#   platoon.
# set-up      :       :       : type is light tank HQ platoon.
#
# set-up      :       :       : creating ground unit medium
#   IFV
#   platoon.
# set-up      :       :       : type is medium IFV platoon.
#
# set-up      :       :       : creating ground unit light
#   IFV
#   platoon.
# set-up      :       :       : type is light IFV platoon.
#
# set-up      :       :       : creating ground unit heavy
#   APC
#   platoon.
# set-up      :       :       : type is heavy APC platoon.
#
# set-up      :       :       : creating ground unit medium
#   APC
#   platoon.
# set-up      :       :       : type is medium APC platoon.
#
# set-up      :       :       : creating ground unit light
#   APC
#   platoon.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit truck
#   platoon.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit light
#   truck
#   platoon.
# set-up      :       :       : type is light truck platoon.
#
# set-up      :       :       : creating ground unit light
#   truck
#   section.
# set-up      :       :       : type is light truck section.
#
# set-up      :       :       : creating ground unit light
#   truck
#   squad.
# set-up      :       :       : type is light truck squad.
#
# set-up      :       :       : creating ground unit towed
#   artillery
#   battery.
# set-up      :       :       : type is towed artillery battery.
#
# set-up      :       :       : creating ground unit armored
#   artillery
#   battery.
# set-up      :       :       : type is armored artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   artillery
#   battery.
# set-up      :       :       : type is mobile artillery battery.
#
# set-up      :       :       : creating ground unit armored
#   rocket
#   artillery
#   battery.
# set-up      :       :       : type is armored rocket artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   rocket
#   artillery
#   battery.
# set-up      :       :       : type is mobile rocket artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   missile
#   artillery
#   battery.
# set-up      :       :       : type is mobile missile artillery battery.

# %%
# !mv map-00.png figure-ground-combat-units.png

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "M2 platoon",
        "DShK-38 platoon",
        "M16 section",
        "M55 battery",
        # "mobile M55 section",
        "ZPU-1 battery",
        "ZPU-2 battery",
        "ZPU-4 battery",
        "mobile ZPU-4 section",
        "TCM-20 battery",
        "M3 TCM-20 section",
        "Rh-202 battery",
        "Panhard M3 DCA section",
        "M163 section",
        "M167 battery",
        "ZU-23 battery",
        "mobile ZU-23 section",
        "ZSU-23-4 section",
        "LAV-AD section",
        "M53/59 section",
        "AMX-30SA section",
        "Tunguska section",
        "Tunguska-M section",
        # "Pantsir section",
        "Oerlikon GDF battery",
        "Gepard section",
        "M-38 battery",
        "Bofors L/60 battery",
        "Bofors L/70 battery",
        "Bofors L/70 BOFI battery",
        "Bofors L/70 BOFI-R battery",
        "S-60 battery",
        "KS-12 battery",
        "KS-19 battery",
    ]:
        if s != "":
            if s.startswith("KS"):
                azimuth = "ENE"
            else:
                azimuth = None
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = s.replace(" ", "\n  ")
            setupgroundunit(
                name, hexcode, s, azimuth=azimuth, color="lightgreen", identified=True, counter=counter,
            )
        if y == 9:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=12.5, ymin=15.5, ymax=23.5)
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit M2
#   platoon.
# set-up      :       :       : type is M2 platoon.
#
# set-up      :       :       : creating ground unit DShK-38
#   platoon.
# set-up      :       :       : type is DShK-38 platoon.
#
# set-up      :       :       : creating ground unit M16
#   section.
# set-up      :       :       : type is M16 section.
#
# set-up      :       :       : creating ground unit M55
#   battery.
# set-up      :       :       : type is M55 battery.
#
# set-up      :       :       : creating ground unit ZPU-1
#   battery.
# set-up      :       :       : type is ZPU-1 battery.
#
# set-up      :       :       : creating ground unit ZPU-2
#   battery.
# set-up      :       :       : type is ZPU-2 battery.
#
# set-up      :       :       : creating ground unit ZPU-4
#   battery.
# set-up      :       :       : type is ZPU-4 battery.
#
# set-up      :       :       : creating ground unit mobile
#   ZPU-4
#   section.
# set-up      :       :       : type is mobile ZPU-4 section.
#
# set-up      :       :       : creating ground unit TCM-20
#   battery.
# set-up      :       :       : type is TCM-20 battery.
#
# set-up      :       :       : creating ground unit M3
#   TCM-20
#   section.
# set-up      :       :       : type is M3 TCM-20 section.
#
# set-up      :       :       : creating ground unit Rh-202
#   battery.
# set-up      :       :       : type is Rh-202 battery.
#
# set-up      :       :       : creating ground unit Panhard
#   M3
#   DCA
#   section.
# set-up      :       :       : type is Panhard M3 DCA section.
#
# set-up      :       :       : creating ground unit M163
#   section.
# set-up      :       :       : type is M163 section.
#
# set-up      :       :       : creating ground unit M167
#   battery.
# set-up      :       :       : type is M167 battery.
#
# set-up      :       :       : creating ground unit ZU-23
#   battery.
# set-up      :       :       : type is ZU-23 battery.
#
# set-up      :       :       : creating ground unit mobile
#   ZU-23
#   section.
# set-up      :       :       : type is mobile ZU-23 section.
#
# set-up      :       :       : creating ground unit ZSU-23-4
#   section.
# set-up      :       :       : type is ZSU-23-4 section.
#
# set-up      :       :       : creating ground unit LAV-AD
#   section.
# set-up      :       :       : type is LAV-AD section.
#
# set-up      :       :       : creating ground unit M53/59
#   section.
# set-up      :       :       : type is M53/59 section.
#
# set-up      :       :       : creating ground unit AMX-30SA
#   section.
# set-up      :       :       : type is AMX-30SA section.
#
# set-up      :       :       : creating ground unit Tunguska
#   section.
# set-up      :       :       : type is Tunguska section.
#
# set-up      :       :       : creating ground unit Tunguska-M
#   section.
# set-up      :       :       : type is Tunguska-M section.
#
# set-up      :       :       : creating ground unit Oerlikon
#   GDF
#   battery.
# set-up      :       :       : type is Oerlikon GDF battery.
#
# set-up      :       :       : creating ground unit Gepard
#   section.
# set-up      :       :       : type is Gepard section.
#
# set-up      :       :       : creating ground unit M-38
#   battery.
# set-up      :       :       : type is M-38 battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/60
#   battery.
# set-up      :       :       : type is Bofors L/60 battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   battery.
# set-up      :       :       : type is Bofors L/70 battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   BOFI
#   battery.
# set-up      :       :       : type is Bofors L/70 BOFI battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   BOFI-R
#   battery.
# set-up      :       :       : type is Bofors L/70 BOFI-R battery.
#
# set-up      :       :       : creating ground unit S-60
#   battery.
# set-up      :       :       : type is S-60 battery.
#
# set-up      :       :       : creating ground unit KS-12
#   battery.
# set-up      :       :       : type is KS-12 battery.
#
# set-up      :       :       : creating ground unit KS-19
#   battery.
# set-up      :       :       : type is KS-19 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit M2
#   platoon.
# set-up      :       :       : type is M2 platoon.
#
# set-up      :       :       : creating ground unit DShK-38
#   platoon.
# set-up      :       :       : type is DShK-38 platoon.
#
# set-up      :       :       : creating ground unit M16
#   section.
# set-up      :       :       : type is M16 section.
#
# set-up      :       :       : creating ground unit M55
#   battery.
# set-up      :       :       : type is M55 battery.
#
# set-up      :       :       : creating ground unit ZPU-1
#   battery.
# set-up      :       :       : type is ZPU-1 battery.
#
# set-up      :       :       : creating ground unit ZPU-2
#   battery.
# set-up      :       :       : type is ZPU-2 battery.
#
# set-up      :       :       : creating ground unit ZPU-4
#   battery.
# set-up      :       :       : type is ZPU-4 battery.
#
# set-up      :       :       : creating ground unit mobile
#   ZPU-4
#   section.
# set-up      :       :       : type is mobile ZPU-4 section.
#
# set-up      :       :       : creating ground unit TCM-20
#   battery.
# set-up      :       :       : type is TCM-20 battery.
#
# set-up      :       :       : creating ground unit M3
#   TCM-20
#   section.
# set-up      :       :       : type is M3 TCM-20 section.
#
# set-up      :       :       : creating ground unit Rh-202
#   battery.
# set-up      :       :       : type is Rh-202 battery.
#
# set-up      :       :       : creating ground unit Panhard
#   M3
#   DCA
#   section.
# set-up      :       :       : type is Panhard M3 DCA section.
#
# set-up      :       :       : creating ground unit M163
#   section.
# set-up      :       :       : type is M163 section.
#
# set-up      :       :       : creating ground unit M167
#   battery.
# set-up      :       :       : type is M167 battery.
#
# set-up      :       :       : creating ground unit ZU-23
#   battery.
# set-up      :       :       : type is ZU-23 battery.
#
# set-up      :       :       : creating ground unit mobile
#   ZU-23
#   section.
# set-up      :       :       : type is mobile ZU-23 section.
#
# set-up      :       :       : creating ground unit ZSU-23-4
#   section.
# set-up      :       :       : type is ZSU-23-4 section.
#
# set-up      :       :       : creating ground unit LAV-AD
#   section.
# set-up      :       :       : type is LAV-AD section.
#
# set-up      :       :       : creating ground unit M53/59
#   section.
# set-up      :       :       : type is M53/59 section.
#
# set-up      :       :       : creating ground unit AMX-30SA
#   section.
# set-up      :       :       : type is AMX-30SA section.
#
# set-up      :       :       : creating ground unit Tunguska
#   section.
# set-up      :       :       : type is Tunguska section.
#
# set-up      :       :       : creating ground unit Tunguska-M
#   section.
# set-up      :       :       : type is Tunguska-M section.
#
# set-up      :       :       : creating ground unit Oerlikon
#   GDF
#   battery.
# set-up      :       :       : type is Oerlikon GDF battery.
#
# set-up      :       :       : creating ground unit Gepard
#   section.
# set-up      :       :       : type is Gepard section.
#
# set-up      :       :       : creating ground unit M-38
#   battery.
# set-up      :       :       : type is M-38 battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/60
#   battery.
# set-up      :       :       : type is Bofors L/60 battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   battery.
# set-up      :       :       : type is Bofors L/70 battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   BOFI
#   battery.
# set-up      :       :       : type is Bofors L/70 BOFI battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   BOFI-R
#   battery.
# set-up      :       :       : type is Bofors L/70 BOFI-R battery.
#
# set-up      :       :       : creating ground unit S-60
#   battery.
# set-up      :       :       : type is S-60 battery.
#
# set-up      :       :       : creating ground unit KS-12
#   battery.
# set-up      :       :       : type is KS-12 battery.
#
# set-up      :       :       : creating ground unit KS-19
#   battery.
# set-up      :       :       : type is KS-19 battery.

# %%
# !mv map-00.png figure-aaa.png

# %%
for counter in [True, False]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "SA-2B battery",
        "SA-2C battery",
        "SA-2E battery",
        "SA-2F battery",
        "SA-3A battery",
        "SA-3B section",
        "SA-4 battery",
        "SA-5 battery",
        "SA-6 battery",
        "SA-8A squad",
        "SA-8B squad",
        "SA-9 squad",
        "SA-10A battery",
        "SA-10B battery",
        "SA-11 squad",
        "SA-12A battery",
        "SA-12B battery",
        "SA-13 squad",
        "SA-15 squad",
        "Tunguska squad",
        "Pantsir S1 squad",
        "SA-17 squad",
        "Pantsir S1M squad",
    ]:
        if s != "":
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = s.replace(" ", "\n  ")
            setupgroundunit(name, hexcode, s, color="lightgreen", counter=counter, identified=True)
        if y == 8:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=12.5, ymin=16.5, ymax=23.5)
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit SA-2B
#   battery.
# set-up      :       :       : type is SA-2B battery.
#
# set-up      :       :       : creating ground unit SA-2C
#   battery.
# set-up      :       :       : type is SA-2C battery.
#
# set-up      :       :       : creating ground unit SA-2E
#   battery.
# set-up      :       :       : type is SA-2E battery.
#
# set-up      :       :       : creating ground unit SA-2F
#   battery.
# set-up      :       :       : type is SA-2F battery.
#
# set-up      :       :       : creating ground unit SA-3A
#   battery.
# set-up      :       :       : type is SA-3A battery.
#
# set-up      :       :       : creating ground unit SA-3B
#   section.
# set-up      :       :       : type is SA-3B section.
#
# set-up      :       :       : creating ground unit SA-4
#   battery.
# set-up      :       :       : type is SA-4 battery.
#
# set-up      :       :       : creating ground unit SA-5
#   battery.
# set-up      :       :       : type is SA-5 battery.
#
# set-up      :       :       : creating ground unit SA-6
#   battery.
# set-up      :       :       : type is SA-6 battery.
#
# set-up      :       :       : creating ground unit SA-8A
#   squad.
# set-up      :       :       : type is SA-8A squad.
#
# set-up      :       :       : creating ground unit SA-8B
#   squad.
# set-up      :       :       : type is SA-8B squad.
#
# set-up      :       :       : creating ground unit SA-9
#   squad.
# set-up      :       :       : type is SA-9 squad.
#
# set-up      :       :       : creating ground unit SA-10A
#   battery.
# set-up      :       :       : type is SA-10A battery.
#
# set-up      :       :       : creating ground unit SA-10B
#   battery.
# set-up      :       :       : type is SA-10B battery.
#
# set-up      :       :       : creating ground unit SA-11
#   squad.
# set-up      :       :       : type is SA-11 squad.
#
# set-up      :       :       : creating ground unit SA-12A
#   battery.
# set-up      :       :       : type is SA-12A battery.
#
# set-up      :       :       : creating ground unit SA-12B
#   battery.
# set-up      :       :       : type is SA-12B battery.
#
# set-up      :       :       : creating ground unit SA-13
#   squad.
# set-up      :       :       : type is SA-13 squad.
#
# set-up      :       :       : creating ground unit SA-15
#   squad.
# set-up      :       :       : type is SA-15 squad.
#
# set-up      :       :       : creating ground unit Tunguska
#   squad.
# set-up      :       :       : type is Tunguska squad.
#
# === ERROR: unable to find ground unit data file for "Tunguska squad". ===
#
#
# set-up      :       :       : creating ground unit Pantsir
#   S1
#   squad.
# set-up      :       :       : type is Pantsir S1 squad.
#
# === ERROR: unable to find ground unit data file for "Pantsir S1 squad". ===
#
#
# set-up      :       :       : creating ground unit SA-17
#   squad.
# set-up      :       :       : type is SA-17 squad.
#
# set-up      :       :       : creating ground unit Pantsir
#   S1M
#   squad.
# set-up      :       :       : type is Pantsir S1M squad.
#
# === ERROR: unable to find ground unit data file for "Pantsir S1M squad". ===
#
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit SA-2B
#   battery.
# set-up      :       :       : type is SA-2B battery.
#
# set-up      :       :       : creating ground unit SA-2C
#   battery.
# set-up      :       :       : type is SA-2C battery.
#
# set-up      :       :       : creating ground unit SA-2E
#   battery.
# set-up      :       :       : type is SA-2E battery.
#
# set-up      :       :       : creating ground unit SA-2F
#   battery.
# set-up      :       :       : type is SA-2F battery.
#
# set-up      :       :       : creating ground unit SA-3A
#   battery.
# set-up      :       :       : type is SA-3A battery.
#
# set-up      :       :       : creating ground unit SA-3B
#   section.
# set-up      :       :       : type is SA-3B section.
#
# set-up      :       :       : creating ground unit SA-4
#   battery.
# set-up      :       :       : type is SA-4 battery.
#
# set-up      :       :       : creating ground unit SA-5
#   battery.
# set-up      :       :       : type is SA-5 battery.
#
# set-up      :       :       : creating ground unit SA-6
#   battery.
# set-up      :       :       : type is SA-6 battery.
#
# set-up      :       :       : creating ground unit SA-8A
#   squad.
# set-up      :       :       : type is SA-8A squad.
#
# set-up      :       :       : creating ground unit SA-8B
#   squad.
# set-up      :       :       : type is SA-8B squad.
#
# set-up      :       :       : creating ground unit SA-9
#   squad.
# set-up      :       :       : type is SA-9 squad.
#
# set-up      :       :       : creating ground unit SA-10A
#   battery.
# set-up      :       :       : type is SA-10A battery.
#
# set-up      :       :       : creating ground unit SA-10B
#   battery.
# set-up      :       :       : type is SA-10B battery.
#
# set-up      :       :       : creating ground unit SA-11
#   squad.
# set-up      :       :       : type is SA-11 squad.
#
# set-up      :       :       : creating ground unit SA-12A
#   battery.
# set-up      :       :       : type is SA-12A battery.
#
# set-up      :       :       : creating ground unit SA-12B
#   battery.
# set-up      :       :       : type is SA-12B battery.
#
# set-up      :       :       : creating ground unit SA-13
#   squad.
# set-up      :       :       : type is SA-13 squad.
#
# set-up      :       :       : creating ground unit SA-15
#   squad.
# set-up      :       :       : type is SA-15 squad.
#
# set-up      :       :       : creating ground unit Tunguska
#   squad.
# set-up      :       :       : type is Tunguska squad.
#
# === ERROR: unable to find ground unit data file for "Tunguska squad". ===
#
#
# set-up      :       :       : creating ground unit Pantsir
#   S1
#   squad.
# set-up      :       :       : type is Pantsir S1 squad.
#
# === ERROR: unable to find ground unit data file for "Pantsir S1 squad". ===
#
#
# set-up      :       :       : creating ground unit SA-17
#   squad.
# set-up      :       :       : type is SA-17 squad.
#
# set-up      :       :       : creating ground unit Pantsir
#   S1M
#   squad.
# set-up      :       :       : type is Pantsir S1M squad.
#
# === ERROR: unable to find ground unit data file for "Pantsir S1M squad". ===

# %%
# !mv map-00.png figure-sam-launcher.png

# %%
for counter in [True, False]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "towed EWR-A",
        "mobile EWR-A",
        "",
        "",
        "",
        "",
        "towed FCR-A",
        "mobile FCR-A",
        "towed FCR-B",
        "mobile FCR-B",
        "",
        "",
        "towed FCR-C",
        "mobile FCR-C",
        "towed FCR-D",
        "mobile FCR-D",
        "",
        "",
        "mobile CCU",
        "armored CCU",
    ]:
        if s != "":
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = s.replace(" ", "\n  ")
            setupgroundunit(name, hexcode, s, color="lightgreen", counter=counter, identified=True)
        if y == 8:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=12.5, ymin=16.5, ymax=23.5)
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit towed
#   EWR-A.
# set-up      :       :       : type is towed EWR-A.
#
# set-up      :       :       : creating ground unit mobile
#   EWR-A.
# set-up      :       :       : type is mobile EWR-A.
#
# set-up      :       :       : creating ground unit towed
#   FCR-A.
# set-up      :       :       : type is towed FCR-A.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-A.
# set-up      :       :       : type is mobile FCR-A.
#
# set-up      :       :       : creating ground unit towed
#   FCR-B.
# set-up      :       :       : type is towed FCR-B.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-B.
# set-up      :       :       : type is mobile FCR-B.
#
# set-up      :       :       : creating ground unit towed
#   FCR-C.
# set-up      :       :       : type is towed FCR-C.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-C.
# set-up      :       :       : type is mobile FCR-C.
#
# set-up      :       :       : creating ground unit towed
#   FCR-D.
# set-up      :       :       : type is towed FCR-D.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-D.
# set-up      :       :       : type is mobile FCR-D.
#
# set-up      :       :       : creating ground unit mobile
#   CCU.
# set-up      :       :       : type is mobile CCU.
#
# === ERROR: unable to find ground unit data file for "mobile CCU". ===
#
#
# set-up      :       :       : creating ground unit armored
#   CCU.
# set-up      :       :       : type is armored CCU.
#
# === ERROR: unable to find ground unit data file for "armored CCU". ===
#
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit towed
#   EWR-A.
# set-up      :       :       : type is towed EWR-A.
#
# set-up      :       :       : creating ground unit mobile
#   EWR-A.
# set-up      :       :       : type is mobile EWR-A.
#
# set-up      :       :       : creating ground unit towed
#   FCR-A.
# set-up      :       :       : type is towed FCR-A.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-A.
# set-up      :       :       : type is mobile FCR-A.
#
# set-up      :       :       : creating ground unit towed
#   FCR-B.
# set-up      :       :       : type is towed FCR-B.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-B.
# set-up      :       :       : type is mobile FCR-B.
#
# set-up      :       :       : creating ground unit towed
#   FCR-C.
# set-up      :       :       : type is towed FCR-C.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-C.
# set-up      :       :       : type is mobile FCR-C.
#
# set-up      :       :       : creating ground unit towed
#   FCR-D.
# set-up      :       :       : type is towed FCR-D.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-D.
# set-up      :       :       : type is mobile FCR-D.
#
# set-up      :       :       : creating ground unit mobile
#   CCU.
# set-up      :       :       : type is mobile CCU.
#
# === ERROR: unable to find ground unit data file for "mobile CCU". ===
#
#
# set-up      :       :       : creating ground unit armored
#   CCU.
# set-up      :       :       : type is armored CCU.
#
# === ERROR: unable to find ground unit data file for "armored CCU". ===

# %%
for counter in [True, False]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [

        "infantry",
        "infantry HQ",
        "infantry FAC",
        "",
        "",
        "",

        "heavy tank",
        "medium tank",
        "light tank",
        "heavy tank HQ",
        "medium tank HQ",
        "light tank HQ",

        "medium IFV",
        "light IFV",
        "heavy APC",
        "medium APC",
        "light APC",
        "",


        "truck",
        "light truck",
        "light truck section",
        "light truck squad",
        "",
        "",

        "towed artillery",
        "armored artillery",
        "mobile artillery",
        "armored rocket artillery",
        "mobile rocket artillery",
        "mobile missile artillery",

    ]:
        if s != "":
            if s.startswith("KS"):
                azimuth = "ENE"
            else:
                azimuth = None
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = s.replace(" ", "\n  ")
            setupgroundunit(name, hexcode, s, azimuth=azimuth, color="lightgreen", counter=counter, sighted=True, identified=False)
        if y == 8:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False,xmin=1.5,xmax=12.5,ymin=16.5,ymax=23.5)
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit infantry.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit infantry
#   HQ.
# set-up      :       :       : type is infantry HQ.
#
# === ERROR: unable to find ground unit data file for "infantry HQ". ===
#
#
# set-up      :       :       : creating ground unit infantry
#   FAC.
# set-up      :       :       : type is infantry FAC.
#
# === ERROR: unable to find ground unit data file for "infantry FAC". ===
#
#
# set-up      :       :       : creating ground unit heavy
#   tank.
# set-up      :       :       : type is heavy tank.
#
# === ERROR: unable to find ground unit data file for "heavy tank". ===
#
#
# set-up      :       :       : creating ground unit medium
#   tank.
# set-up      :       :       : type is medium tank.
#
# === ERROR: unable to find ground unit data file for "medium tank". ===
#
#
# set-up      :       :       : creating ground unit light
#   tank.
# set-up      :       :       : type is light tank.
#
# === ERROR: unable to find ground unit data file for "light tank". ===
#
#
# set-up      :       :       : creating ground unit heavy
#   tank
#   HQ.
# set-up      :       :       : type is heavy tank HQ.
#
# === ERROR: unable to find ground unit data file for "heavy tank HQ". ===
#
#
# set-up      :       :       : creating ground unit medium
#   tank
#   HQ.
# set-up      :       :       : type is medium tank HQ.
#
# === ERROR: unable to find ground unit data file for "medium tank HQ". ===
#
#
# set-up      :       :       : creating ground unit light
#   tank
#   HQ.
# set-up      :       :       : type is light tank HQ.
#
# === ERROR: unable to find ground unit data file for "light tank HQ". ===
#
#
# set-up      :       :       : creating ground unit medium
#   IFV.
# set-up      :       :       : type is medium IFV.
#
# === ERROR: unable to find ground unit data file for "medium IFV". ===
#
#
# set-up      :       :       : creating ground unit light
#   IFV.
# set-up      :       :       : type is light IFV.
#
# === ERROR: unable to find ground unit data file for "light IFV". ===
#
#
# set-up      :       :       : creating ground unit heavy
#   APC.
# set-up      :       :       : type is heavy APC.
#
# === ERROR: unable to find ground unit data file for "heavy APC". ===
#
#
# set-up      :       :       : creating ground unit medium
#   APC.
# set-up      :       :       : type is medium APC.
#
# === ERROR: unable to find ground unit data file for "medium APC". ===
#
#
# set-up      :       :       : creating ground unit light
#   APC.
# set-up      :       :       : type is light APC.
#
# === ERROR: unable to find ground unit data file for "light APC". ===
#
#
# set-up      :       :       : creating ground unit truck.
# set-up      :       :       : type is truck.
#
# === ERROR: unable to find ground unit data file for "truck". ===
#
#
# set-up      :       :       : creating ground unit light
#   truck.
# set-up      :       :       : type is light truck.
#
# === ERROR: unable to find ground unit data file for "light truck". ===
#
#
# set-up      :       :       : creating ground unit light
#   truck
#   section.
# set-up      :       :       : type is light truck section.
#
# set-up      :       :       : creating ground unit light
#   truck
#   squad.
# set-up      :       :       : type is light truck squad.
#
# set-up      :       :       : creating ground unit towed
#   artillery.
# set-up      :       :       : type is towed artillery.
#
# === ERROR: unable to find ground unit data file for "towed artillery". ===
#
#
# set-up      :       :       : creating ground unit armored
#   artillery.
# set-up      :       :       : type is armored artillery.
#
# === ERROR: unable to find ground unit data file for "armored artillery". ===
#
#
# set-up      :       :       : creating ground unit mobile
#   artillery.
# set-up      :       :       : type is mobile artillery.
#
# === ERROR: unable to find ground unit data file for "mobile artillery". ===
#
#
# set-up      :       :       : creating ground unit armored
#   rocket
#   artillery.
# set-up      :       :       : type is armored rocket artillery.
#
# === ERROR: unable to find ground unit data file for "armored rocket artillery". ===
#
#
# set-up      :       :       : creating ground unit mobile
#   rocket
#   artillery.
# set-up      :       :       : type is mobile rocket artillery.
#
# === ERROR: unable to find ground unit data file for "mobile rocket artillery". ===
#
#
# set-up      :       :       : creating ground unit mobile
#   missile
#   artillery.
# set-up      :       :       : type is mobile missile artillery.
#
# === ERROR: unable to find ground unit data file for "mobile missile artillery". ===
#
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit infantry.
# set-up      :       :       : type is infantry.
#
# set-up      :       :       : creating ground unit infantry
#   HQ.
# set-up      :       :       : type is infantry HQ.
#
# === ERROR: unable to find ground unit data file for "infantry HQ". ===
#
#
# set-up      :       :       : creating ground unit infantry
#   FAC.
# set-up      :       :       : type is infantry FAC.
#
# === ERROR: unable to find ground unit data file for "infantry FAC". ===
#
#
# set-up      :       :       : creating ground unit heavy
#   tank.
# set-up      :       :       : type is heavy tank.
#
# === ERROR: unable to find ground unit data file for "heavy tank". ===
#
#
# set-up      :       :       : creating ground unit medium
#   tank.
# set-up      :       :       : type is medium tank.
#
# === ERROR: unable to find ground unit data file for "medium tank". ===
#
#
# set-up      :       :       : creating ground unit light
#   tank.
# set-up      :       :       : type is light tank.
#
# === ERROR: unable to find ground unit data file for "light tank". ===
#
#
# set-up      :       :       : creating ground unit heavy
#   tank
#   HQ.
# set-up      :       :       : type is heavy tank HQ.
#
# === ERROR: unable to find ground unit data file for "heavy tank HQ". ===
#
#
# set-up      :       :       : creating ground unit medium
#   tank
#   HQ.
# set-up      :       :       : type is medium tank HQ.
#
# === ERROR: unable to find ground unit data file for "medium tank HQ". ===
#
#
# set-up      :       :       : creating ground unit light
#   tank
#   HQ.
# set-up      :       :       : type is light tank HQ.
#
# === ERROR: unable to find ground unit data file for "light tank HQ". ===
#
#
# set-up      :       :       : creating ground unit medium
#   IFV.
# set-up      :       :       : type is medium IFV.
#
# === ERROR: unable to find ground unit data file for "medium IFV". ===
#
#
# set-up      :       :       : creating ground unit light
#   IFV.
# set-up      :       :       : type is light IFV.
#
# === ERROR: unable to find ground unit data file for "light IFV". ===
#
#
# set-up      :       :       : creating ground unit heavy
#   APC.
# set-up      :       :       : type is heavy APC.
#
# === ERROR: unable to find ground unit data file for "heavy APC". ===
#
#
# set-up      :       :       : creating ground unit medium
#   APC.
# set-up      :       :       : type is medium APC.
#
# === ERROR: unable to find ground unit data file for "medium APC". ===
#
#
# set-up      :       :       : creating ground unit light
#   APC.
# set-up      :       :       : type is light APC.
#
# === ERROR: unable to find ground unit data file for "light APC". ===
#
#
# set-up      :       :       : creating ground unit truck.
# set-up      :       :       : type is truck.
#
# === ERROR: unable to find ground unit data file for "truck". ===
#
#
# set-up      :       :       : creating ground unit light
#   truck.
# set-up      :       :       : type is light truck.
#
# === ERROR: unable to find ground unit data file for "light truck". ===
#
#
# set-up      :       :       : creating ground unit light
#   truck
#   section.
# set-up      :       :       : type is light truck section.
#
# set-up      :       :       : creating ground unit light
#   truck
#   squad.
# set-up      :       :       : type is light truck squad.
#
# set-up      :       :       : creating ground unit towed
#   artillery.
# set-up      :       :       : type is towed artillery.
#
# === ERROR: unable to find ground unit data file for "towed artillery". ===
#
#
# set-up      :       :       : creating ground unit armored
#   artillery.
# set-up      :       :       : type is armored artillery.
#
# === ERROR: unable to find ground unit data file for "armored artillery". ===
#
#
# set-up      :       :       : creating ground unit mobile
#   artillery.
# set-up      :       :       : type is mobile artillery.
#
# === ERROR: unable to find ground unit data file for "mobile artillery". ===
#
#
# set-up      :       :       : creating ground unit armored
#   rocket
#   artillery.
# set-up      :       :       : type is armored rocket artillery.
#
# === ERROR: unable to find ground unit data file for "armored rocket artillery". ===
#
#
# set-up      :       :       : creating ground unit mobile
#   rocket
#   artillery.
# set-up      :       :       : type is mobile rocket artillery.
#
# === ERROR: unable to find ground unit data file for "mobile rocket artillery". ===
#
#
# set-up      :       :       : creating ground unit mobile
#   missile
#   artillery.
# set-up      :       :       : type is mobile missile artillery.
#
# === ERROR: unable to find ground unit data file for "mobile missile artillery". ===
