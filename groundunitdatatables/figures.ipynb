# %%
import sys
print(sys.path)
# Out:
# ['/Users/alan/GitHub/Home/glass/src', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python313.zip', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python3.13', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python3.13/lib-dynload', '', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python3.13/site-packages']

# %%
from glass import *

# %%
def prettyname(name, counter):
    if counter:
        name = name.replace(" ", "\n  ")
        #name = name.replace("\n  squad", "")
        #name = name.replace("\n  section", " ")
        #name = name.replace("\n  platoon", "  ")
        #name = name.replace("\n  battery", "   ")
    else:
        name = name.replace(" squad", "")
        name = name.replace(" section", " ")
        name = name.replace(" platoon", "  ")
        name = name.replace(" battery", "   ")        
    return name

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [

        "infantry platoon",
        "infantry HQ platoon",
        "infantry FAC section",
        "infantry FAC squad",
        "",
        "",
        "",
        "",

        "heavy tank platoon",
        "heavy tank HQ platoon",
        "medium tank platoon",
        "medium tank HQ platoon",
        "light tank platoon",
        "light tank HQ platoon",
        "open tank platoon",
        "open tank HQ platoon",

        "light anti-tank platoon",
        "medium IFV platoon",
        "light IFV platoon",
        "heavy APC platoon",
        "medium APC platoon",
        "light APC platoon",
        "open APC platoon",
        "",

        "truck platoon",
        "truck section",
        "truck squad",
        "tracked carrier platoon",
        "",
        "",
        "",
        "",

        "armored artillery battery",
        "tracked artillery battery",
        "mobile artillery battery",
        "towed artillery battery",
        "armored rocket artillery battery",
        "mobile rocket artillery battery",
        "tracked missile artillery battery",
        "mobile missile artillery battery",

    ]:
        if s != "":
            if s.startswith("KS"):
                azimuth = "ENE"
            else:
                azimuth = None
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(name, hexcode, s, azimuth=azimuth, color="lightgreen", counter=counter, identified=True)
        if y == 10:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False,xmin=1.5,xmax=13.5,ymin=14.5,ymax=23.5)

# !mv map-00.png figure-ground-combat-units.png
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit infantry  .
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit infantry HQ  .
# set-up      :       :       : type is infantry HQ platoon.
#
# set-up      :       :       : creating ground unit infantry FAC .
# set-up      :       :       : type is infantry FAC section.
#
# set-up      :       :       : creating ground unit infantry FAC.
# set-up      :       :       : type is infantry FAC squad.
#
# set-up      :       :       : creating ground unit heavy tank  .
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit heavy tank HQ  .
# set-up      :       :       : type is heavy tank HQ platoon.
#
# set-up      :       :       : creating ground unit medium tank  .
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit medium tank HQ  .
# set-up      :       :       : type is medium tank HQ platoon.
#
# set-up      :       :       : creating ground unit light tank  .
# set-up      :       :       : type is light tank platoon.
#
# set-up      :       :       : creating ground unit light tank HQ  .
# set-up      :       :       : type is light tank HQ platoon.
#
# set-up      :       :       : creating ground unit open tank  .
# set-up      :       :       : type is open tank platoon.
#
# set-up      :       :       : creating ground unit open tank HQ  .
# set-up      :       :       : type is open tank HQ platoon.
#
# set-up      :       :       : creating ground unit light anti-tank  .
# set-up      :       :       : type is light anti-tank platoon.
#
# set-up      :       :       : creating ground unit medium IFV  .
# set-up      :       :       : type is medium IFV platoon.
#
# set-up      :       :       : creating ground unit light IFV  .
# set-up      :       :       : type is light IFV platoon.
#
# set-up      :       :       : creating ground unit heavy APC  .
# set-up      :       :       : type is heavy APC platoon.
#
# set-up      :       :       : creating ground unit medium APC  .
# set-up      :       :       : type is medium APC platoon.
#
# set-up      :       :       : creating ground unit light APC  .
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit open APC  .
# set-up      :       :       : type is open APC platoon.
#
# set-up      :       :       : creating ground unit truck  .
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit truck .
# set-up      :       :       : type is truck section.
#
# set-up      :       :       : creating ground unit truck.
# set-up      :       :       : type is truck squad.
#
# set-up      :       :       : creating ground unit tracked carrier  .
# set-up      :       :       : type is tracked carrier platoon.
#
# set-up      :       :       : creating ground unit armored artillery   .
# set-up      :       :       : type is armored artillery battery.
#
# set-up      :       :       : creating ground unit tracked artillery   .
# set-up      :       :       : type is tracked artillery battery.
#
# set-up      :       :       : creating ground unit mobile artillery   .
# set-up      :       :       : type is mobile artillery battery.
#
# set-up      :       :       : creating ground unit towed artillery   .
# set-up      :       :       : type is towed artillery battery.
#
# set-up      :       :       : creating ground unit armored rocket artillery   .
# set-up      :       :       : type is armored rocket artillery battery.
#
# set-up      :       :       : creating ground unit mobile rocket artillery   .
# set-up      :       :       : type is mobile rocket artillery battery.
#
# set-up      :       :       : creating ground unit tracked missile artillery   .
# set-up      :       :       : type is tracked missile artillery battery.
#
# set-up      :       :       : creating ground unit mobile missile artillery   .
# set-up      :       :       : type is mobile missile artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit infantry
#   platoon.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit infantry
#   HQ
#   platoon.
# set-up      :       :       : type is infantry HQ platoon.
#
# set-up      :       :       : creating ground unit infantry
#   FAC
#   section.
# set-up      :       :       : type is infantry FAC section.
#
# set-up      :       :       : creating ground unit infantry
#   FAC
#   squad.
# set-up      :       :       : type is infantry FAC squad.
#
# set-up      :       :       : creating ground unit heavy
#   tank
#   platoon.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit heavy
#   tank
#   HQ
#   platoon.
# set-up      :       :       : type is heavy tank HQ platoon.
#
# set-up      :       :       : creating ground unit medium
#   tank
#   platoon.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit medium
#   tank
#   HQ
#   platoon.
# set-up      :       :       : type is medium tank HQ platoon.
#
# set-up      :       :       : creating ground unit light
#   tank
#   platoon.
# set-up      :       :       : type is light tank platoon.
#
# set-up      :       :       : creating ground unit light
#   tank
#   HQ
#   platoon.
# set-up      :       :       : type is light tank HQ platoon.
#
# set-up      :       :       : creating ground unit open
#   tank
#   platoon.
# set-up      :       :       : type is open tank platoon.
#
# set-up      :       :       : creating ground unit open
#   tank
#   HQ
#   platoon.
# set-up      :       :       : type is open tank HQ platoon.
#
# set-up      :       :       : creating ground unit light
#   anti-tank
#   platoon.
# set-up      :       :       : type is light anti-tank platoon.
#
# set-up      :       :       : creating ground unit medium
#   IFV
#   platoon.
# set-up      :       :       : type is medium IFV platoon.
#
# set-up      :       :       : creating ground unit light
#   IFV
#   platoon.
# set-up      :       :       : type is light IFV platoon.
#
# set-up      :       :       : creating ground unit heavy
#   APC
#   platoon.
# set-up      :       :       : type is heavy APC platoon.
#
# set-up      :       :       : creating ground unit medium
#   APC
#   platoon.
# set-up      :       :       : type is medium APC platoon.
#
# set-up      :       :       : creating ground unit light
#   APC
#   platoon.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit open
#   APC
#   platoon.
# set-up      :       :       : type is open APC platoon.
#
# set-up      :       :       : creating ground unit truck
#   platoon.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit truck
#   section.
# set-up      :       :       : type is truck section.
#
# set-up      :       :       : creating ground unit truck
#   squad.
# set-up      :       :       : type is truck squad.
#
# set-up      :       :       : creating ground unit tracked
#   carrier
#   platoon.
# set-up      :       :       : type is tracked carrier platoon.
#
# set-up      :       :       : creating ground unit armored
#   artillery
#   battery.
# set-up      :       :       : type is armored artillery battery.
#
# set-up      :       :       : creating ground unit tracked
#   artillery
#   battery.
# set-up      :       :       : type is tracked artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   artillery
#   battery.
# set-up      :       :       : type is mobile artillery battery.
#
# set-up      :       :       : creating ground unit towed
#   artillery
#   battery.
# set-up      :       :       : type is towed artillery battery.
#
# set-up      :       :       : creating ground unit armored
#   rocket
#   artillery
#   battery.
# set-up      :       :       : type is armored rocket artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   rocket
#   artillery
#   battery.
# set-up      :       :       : type is mobile rocket artillery battery.
#
# set-up      :       :       : creating ground unit tracked
#   missile
#   artillery
#   battery.
# set-up      :       :       : type is tracked missile artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   missile
#   artillery
#   battery.
# set-up      :       :       : type is mobile missile artillery battery.

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "M2 platoon",
        "DShK-38 platoon",
        "M16 section",
        "M55 platoon",
        # "mobile M55 section",
        "ZPU-1 battery",
        "ZPU-2 battery",
        "ZPU-4 battery",
        "mobile ZPU-4 section",
        "TCM-20 platoon",
        "M3 TCM-20 section",
        "Rh-202 battery",
        "Panhard M3 DCA section",
        "M163 section",
        "M167 platoon",
        "ZU-23 battery",
        "mobile ZU-23 section",
        "ZSU-23-4 section",
        "LAV-AD section",
        "M53/59 section",
        "AMX-30SA section",
        "Tunguska section",
        "Tunguska-M section",
        # "Pantsir section",
        "Oerlikon GDF battery",
        "Gepard section",
        "61-K battery",
        "Bofors L/60 battery",
        "Bofors L/70 battery",
        "Bofors L/70 BOFI battery",
        "Bofors L/70 BOFI-R battery",
        "S-60 battery",
        "ZSU-57-2 section",
        "KS-12 battery",
        "KS-19 battery",
    ]:
        if s != "":
            if s.startswith("KS"):
                azimuth = "ENE"
            else:
                azimuth = None
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(
                name, hexcode, s, azimuth=azimuth, color="lightgreen", identified=True, counter=counter,
            )
        if y == 9:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=13.5, ymin=15.5, ymax=23.5)

# !mv map-00.png figure-aaa.png
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit M2  .
# set-up      :       :       : type is M2 platoon.
#
# set-up      :       :       : creating ground unit DShK-38  .
# set-up      :       :       : type is DShK-38 platoon.
#
# set-up      :       :       : creating ground unit M16 .
# set-up      :       :       : type is M16 section.
#
# set-up      :       :       : creating ground unit M55  .
# set-up      :       :       : type is M55 platoon.
#
# set-up      :       :       : creating ground unit ZPU-1   .
# set-up      :       :       : type is ZPU-1 battery.
#
# set-up      :       :       : creating ground unit ZPU-2   .
# set-up      :       :       : type is ZPU-2 battery.
#
# set-up      :       :       : creating ground unit ZPU-4   .
# set-up      :       :       : type is ZPU-4 battery.
#
# set-up      :       :       : creating ground unit mobile ZPU-4 .
# set-up      :       :       : type is mobile ZPU-4 section.
#
# set-up      :       :       : creating ground unit TCM-20  .
# set-up      :       :       : type is TCM-20 platoon.
#
# set-up      :       :       : creating ground unit M3 TCM-20 .
# set-up      :       :       : type is M3 TCM-20 section.
#
# set-up      :       :       : creating ground unit Rh-202   .
# set-up      :       :       : type is Rh-202 battery.
#
# set-up      :       :       : creating ground unit Panhard M3 DCA .
# set-up      :       :       : type is Panhard M3 DCA section.
#
# set-up      :       :       : creating ground unit M163 .
# set-up      :       :       : type is M163 section.
#
# set-up      :       :       : creating ground unit M167  .
# set-up      :       :       : type is M167 platoon.
#
# set-up      :       :       : creating ground unit ZU-23   .
# set-up      :       :       : type is ZU-23 battery.
#
# set-up      :       :       : creating ground unit mobile ZU-23 .
# set-up      :       :       : type is mobile ZU-23 section.
#
# set-up      :       :       : creating ground unit ZSU-23-4 .
# set-up      :       :       : type is ZSU-23-4 section.
#
# set-up      :       :       : creating ground unit LAV-AD .
# set-up      :       :       : type is LAV-AD section.
#
# set-up      :       :       : creating ground unit M53/59 .
# set-up      :       :       : type is M53/59 section.
#
# set-up      :       :       : creating ground unit AMX-30SA .
# set-up      :       :       : type is AMX-30SA section.
#
# set-up      :       :       : creating ground unit Tunguska .
# set-up      :       :       : type is Tunguska section.
#
# set-up      :       :       : creating ground unit Tunguska-M .
# set-up      :       :       : type is Tunguska-M section.
#
# set-up      :       :       : creating ground unit Oerlikon GDF   .
# set-up      :       :       : type is Oerlikon GDF battery.
#
# set-up      :       :       : creating ground unit Gepard .
# set-up      :       :       : type is Gepard section.
#
# set-up      :       :       : creating ground unit 61-K   .
# set-up      :       :       : type is 61-K battery.
#
# set-up      :       :       : creating ground unit Bofors L/60   .
# set-up      :       :       : type is Bofors L/60 battery.
#
# set-up      :       :       : creating ground unit Bofors L/70   .
# set-up      :       :       : type is Bofors L/70 battery.
#
# set-up      :       :       : creating ground unit Bofors L/70 BOFI   .
# set-up      :       :       : type is Bofors L/70 BOFI battery.
#
# set-up      :       :       : creating ground unit Bofors L/70 BOFI-R   .
# set-up      :       :       : type is Bofors L/70 BOFI-R battery.
#
# set-up      :       :       : creating ground unit S-60   .
# set-up      :       :       : type is S-60 battery.
#
# set-up      :       :       : creating ground unit ZSU-57-2 .
# set-up      :       :       : type is ZSU-57-2 section.
#
# set-up      :       :       : creating ground unit KS-12   .
# set-up      :       :       : type is KS-12 battery.
#
# set-up      :       :       : creating ground unit KS-19   .
# set-up      :       :       : type is KS-19 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit M2
#   platoon.
# set-up      :       :       : type is M2 platoon.
#
# set-up      :       :       : creating ground unit DShK-38
#   platoon.
# set-up      :       :       : type is DShK-38 platoon.
#
# set-up      :       :       : creating ground unit M16
#   section.
# set-up      :       :       : type is M16 section.
#
# set-up      :       :       : creating ground unit M55
#   platoon.
# set-up      :       :       : type is M55 platoon.
#
# set-up      :       :       : creating ground unit ZPU-1
#   battery.
# set-up      :       :       : type is ZPU-1 battery.
#
# set-up      :       :       : creating ground unit ZPU-2
#   battery.
# set-up      :       :       : type is ZPU-2 battery.
#
# set-up      :       :       : creating ground unit ZPU-4
#   battery.
# set-up      :       :       : type is ZPU-4 battery.
#
# set-up      :       :       : creating ground unit mobile
#   ZPU-4
#   section.
# set-up      :       :       : type is mobile ZPU-4 section.
#
# set-up      :       :       : creating ground unit TCM-20
#   platoon.
# set-up      :       :       : type is TCM-20 platoon.
#
# set-up      :       :       : creating ground unit M3
#   TCM-20
#   section.
# set-up      :       :       : type is M3 TCM-20 section.
#
# set-up      :       :       : creating ground unit Rh-202
#   battery.
# set-up      :       :       : type is Rh-202 battery.
#
# set-up      :       :       : creating ground unit Panhard
#   M3
#   DCA
#   section.
# set-up      :       :       : type is Panhard M3 DCA section.
#
# set-up      :       :       : creating ground unit M163
#   section.
# set-up      :       :       : type is M163 section.
#
# set-up      :       :       : creating ground unit M167
#   platoon.
# set-up      :       :       : type is M167 platoon.
#
# set-up      :       :       : creating ground unit ZU-23
#   battery.
# set-up      :       :       : type is ZU-23 battery.
#
# set-up      :       :       : creating ground unit mobile
#   ZU-23
#   section.
# set-up      :       :       : type is mobile ZU-23 section.
#
# set-up      :       :       : creating ground unit ZSU-23-4
#   section.
# set-up      :       :       : type is ZSU-23-4 section.
#
# set-up      :       :       : creating ground unit LAV-AD
#   section.
# set-up      :       :       : type is LAV-AD section.
#
# set-up      :       :       : creating ground unit M53/59
#   section.
# set-up      :       :       : type is M53/59 section.
#
# set-up      :       :       : creating ground unit AMX-30SA
#   section.
# set-up      :       :       : type is AMX-30SA section.
#
# set-up      :       :       : creating ground unit Tunguska
#   section.
# set-up      :       :       : type is Tunguska section.
#
# set-up      :       :       : creating ground unit Tunguska-M
#   section.
# set-up      :       :       : type is Tunguska-M section.
#
# set-up      :       :       : creating ground unit Oerlikon
#   GDF
#   battery.
# set-up      :       :       : type is Oerlikon GDF battery.
#
# set-up      :       :       : creating ground unit Gepard
#   section.
# set-up      :       :       : type is Gepard section.
#
# set-up      :       :       : creating ground unit 61-K
#   battery.
# set-up      :       :       : type is 61-K battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/60
#   battery.
# set-up      :       :       : type is Bofors L/60 battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   battery.
# set-up      :       :       : type is Bofors L/70 battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   BOFI
#   battery.
# set-up      :       :       : type is Bofors L/70 BOFI battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   BOFI-R
#   battery.
# set-up      :       :       : type is Bofors L/70 BOFI-R battery.
#
# set-up      :       :       : creating ground unit S-60
#   battery.
# set-up      :       :       : type is S-60 battery.
#
# set-up      :       :       : creating ground unit ZSU-57-2
#   section.
# set-up      :       :       : type is ZSU-57-2 section.
#
# set-up      :       :       : creating ground unit KS-12
#   battery.
# set-up      :       :       : type is KS-12 battery.
#
# set-up      :       :       : creating ground unit KS-19
#   battery.
# set-up      :       :       : type is KS-19 battery.

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "mobile FCR-A platoon",
        "mobile FCR-B platoon",
        "mobile FCR-C platoon",
        "mobile FCR-D platoon",
        "mobile EWR-A platoon",
        "mobile EWR-B platoon",
        "mobile CCU platoon",
        "armored CCU squad",
        "Crotale CCU/EWR squad",
        ""
    ]:
        if s != "":
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(name, hexcode, s, color="lightgreen", counter=counter, identified=True)
        if y == 4:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=13.5, ymin=20.5, ymax=23.5)

# !mv map-00.png figure-radar-and-ccu-units.png
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit mobile FCR-A  .
# set-up      :       :       : type is mobile FCR-A platoon.
#
# set-up      :       :       : creating ground unit mobile FCR-B  .
# set-up      :       :       : type is mobile FCR-B platoon.
#
# set-up      :       :       : creating ground unit mobile FCR-C  .
# set-up      :       :       : type is mobile FCR-C platoon.
#
# set-up      :       :       : creating ground unit mobile FCR-D  .
# set-up      :       :       : type is mobile FCR-D platoon.
#
# set-up      :       :       : creating ground unit mobile EWR-A  .
# set-up      :       :       : type is mobile EWR-A platoon.
#
# set-up      :       :       : creating ground unit mobile EWR-B  .
# set-up      :       :       : type is mobile EWR-B platoon.
#
# set-up      :       :       : creating ground unit mobile CCU  .
# set-up      :       :       : type is mobile CCU platoon.
#
# set-up      :       :       : creating ground unit armored CCU.
# set-up      :       :       : type is armored CCU squad.
#
# set-up      :       :       : creating ground unit Crotale CCU/EWR.
# set-up      :       :       : type is Crotale CCU/EWR squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-A
#   platoon.
# set-up      :       :       : type is mobile FCR-A platoon.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-B
#   platoon.
# set-up      :       :       : type is mobile FCR-B platoon.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-C
#   platoon.
# set-up      :       :       : type is mobile FCR-C platoon.
#
# set-up      :       :       : creating ground unit mobile
#   FCR-D
#   platoon.
# set-up      :       :       : type is mobile FCR-D platoon.
#
# set-up      :       :       : creating ground unit mobile
#   EWR-A
#   platoon.
# set-up      :       :       : type is mobile EWR-A platoon.
#
# set-up      :       :       : creating ground unit mobile
#   EWR-B
#   platoon.
# set-up      :       :       : type is mobile EWR-B platoon.
#
# set-up      :       :       : creating ground unit mobile
#   CCU
#   platoon.
# set-up      :       :       : type is mobile CCU platoon.
#
# set-up      :       :       : creating ground unit armored
#   CCU
#   squad.
# set-up      :       :       : type is armored CCU squad.
#
# set-up      :       :       : creating ground unit Crotale
#   CCU/EWR
#   squad.
# set-up      :       :       : type is Crotale CCU/EWR squad.

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "SA-7A section",
        "SA-7B section",
        "SA-14 section",
        "SA-16 section",
        "SA-18 section",
        "",
        "FIM-43C section",
        "FIM-92A section",
        "FIM-92B section",
        "FIM-92C section",
        "FIM-92D section",
        "",
        "Blowpipe section",
        "Javelin section",
        "Starburst section",
        "Starstreak section",
        "",
        "",
        "Starstreak LML section",
        "Mistral section",
        "RBS 70 section",
    ]:
        if s != "":
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(name, hexcode, s, color="lightgreen", counter=counter, identified=True)
        if y == 8:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=13.5, ymin=16.5, ymax=23.5)

# !mv map-00.png figure-infantry-sam-units.png
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit SA-7A .
# set-up      :       :       : type is SA-7A section.
#
# set-up      :       :       : creating ground unit SA-7B .
# set-up      :       :       : type is SA-7B section.
#
# set-up      :       :       : creating ground unit SA-14 .
# set-up      :       :       : type is SA-14 section.
#
# set-up      :       :       : creating ground unit SA-16 .
# set-up      :       :       : type is SA-16 section.
#
# set-up      :       :       : creating ground unit SA-18 .
# set-up      :       :       : type is SA-18 section.
#
# set-up      :       :       : creating ground unit FIM-43C .
# set-up      :       :       : type is FIM-43C section.
#
# set-up      :       :       : creating ground unit FIM-92A .
# set-up      :       :       : type is FIM-92A section.
#
# set-up      :       :       : creating ground unit FIM-92B .
# set-up      :       :       : type is FIM-92B section.
#
# set-up      :       :       : creating ground unit FIM-92C .
# set-up      :       :       : type is FIM-92C section.
#
# set-up      :       :       : creating ground unit FIM-92D .
# set-up      :       :       : type is FIM-92D section.
#
# set-up      :       :       : creating ground unit Blowpipe .
# set-up      :       :       : type is Blowpipe section.
#
# set-up      :       :       : creating ground unit Javelin .
# set-up      :       :       : type is Javelin section.
#
# set-up      :       :       : creating ground unit Starburst .
# set-up      :       :       : type is Starburst section.
#
# set-up      :       :       : creating ground unit Starstreak .
# set-up      :       :       : type is Starstreak section.
#
# set-up      :       :       : creating ground unit Starstreak LML .
# set-up      :       :       : type is Starstreak LML section.
#
# set-up      :       :       : creating ground unit Mistral .
# set-up      :       :       : type is Mistral section.
#
# set-up      :       :       : creating ground unit RBS 70 .
# set-up      :       :       : type is RBS 70 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit SA-7A
#   section.
# set-up      :       :       : type is SA-7A section.
#
# set-up      :       :       : creating ground unit SA-7B
#   section.
# set-up      :       :       : type is SA-7B section.
#
# set-up      :       :       : creating ground unit SA-14
#   section.
# set-up      :       :       : type is SA-14 section.
#
# set-up      :       :       : creating ground unit SA-16
#   section.
# set-up      :       :       : type is SA-16 section.
#
# set-up      :       :       : creating ground unit SA-18
#   section.
# set-up      :       :       : type is SA-18 section.
#
# set-up      :       :       : creating ground unit FIM-43C
#   section.
# set-up      :       :       : type is FIM-43C section.
#
# set-up      :       :       : creating ground unit FIM-92A
#   section.
# set-up      :       :       : type is FIM-92A section.
#
# set-up      :       :       : creating ground unit FIM-92B
#   section.
# set-up      :       :       : type is FIM-92B section.
#
# set-up      :       :       : creating ground unit FIM-92C
#   section.
# set-up      :       :       : type is FIM-92C section.
#
# set-up      :       :       : creating ground unit FIM-92D
#   section.
# set-up      :       :       : type is FIM-92D section.
#
# set-up      :       :       : creating ground unit Blowpipe
#   section.
# set-up      :       :       : type is Blowpipe section.
#
# set-up      :       :       : creating ground unit Javelin
#   section.
# set-up      :       :       : type is Javelin section.
#
# set-up      :       :       : creating ground unit Starburst
#   section.
# set-up      :       :       : type is Starburst section.
#
# set-up      :       :       : creating ground unit Starstreak
#   section.
# set-up      :       :       : type is Starstreak section.
#
# set-up      :       :       : creating ground unit Starstreak
#   LML
#   section.
# set-up      :       :       : type is Starstreak LML section.
#
# set-up      :       :       : creating ground unit Mistral
#   section.
# set-up      :       :       : type is Mistral section.
#
# set-up      :       :       : creating ground unit RBS
#   70
#   section.
# set-up      :       :       : type is RBS 70 section.

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "SA-2B battery",
        "SA-2C battery",
        "SA-2E battery",
        "SA-2F battery",
        "SA-3B battery",
        "mobile SA-3B battery",
        "SA-4A battery",
        "SA-4B battery",
        "SA-6A battery",
        "SA-6B battery",
        "SA-7A section",
        "SA-7B section",
        "SA-8A squad",
        "SA-8B squad",
        "SA-9A squad",
        "SA-9B squad",
        "SA-11 squad",
        "SA-13 squad",
        "SA-14 section",
        #"SA-5 battery",
        #"SA-10A battery",
        #"SA-10B battery",
        #"SA-12A battery",
        #"SA-12B battery",
        #"SA-13 squad",
        #"SA-15 squad",
        #"SA-17 squad",
        #"Tunguska section",
        #"Pantsir section",
        "M48 squad",
        "I-HAWK platoon",
        "MIM-104A battery",
    ]:
        if s != "":
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(name, hexcode, s, color="lightgreen", counter=counter, identified=True)
        if y == 8:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=13.5, ymin=16.5, ymax=23.5)

# !mv map-00.png figure-sam-launcher.png
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit SA-2B   .
# set-up      :       :       : type is SA-2B battery.
#
# set-up      :       :       : creating ground unit SA-2C   .
# set-up      :       :       : type is SA-2C battery.
#
# set-up      :       :       : creating ground unit SA-2E   .
# set-up      :       :       : type is SA-2E battery.
#
# set-up      :       :       : creating ground unit SA-2F   .
# set-up      :       :       : type is SA-2F battery.
#
# set-up      :       :       : creating ground unit SA-3B   .
# set-up      :       :       : type is SA-3B battery.
#
# set-up      :       :       : creating ground unit mobile SA-3B   .
# set-up      :       :       : type is mobile SA-3B battery.
#
# set-up      :       :       : creating ground unit SA-4A   .
# set-up      :       :       : type is SA-4A battery.
#
# set-up      :       :       : creating ground unit SA-4B   .
# set-up      :       :       : type is SA-4B battery.
#
# set-up      :       :       : creating ground unit SA-6A   .
# set-up      :       :       : type is SA-6A battery.
#
# set-up      :       :       : creating ground unit SA-6B   .
# set-up      :       :       : type is SA-6B battery.
#
# set-up      :       :       : creating ground unit SA-7A .
# set-up      :       :       : type is SA-7A section.
#
# set-up      :       :       : creating ground unit SA-7B .
# set-up      :       :       : type is SA-7B section.
#
# set-up      :       :       : creating ground unit SA-8A.
# set-up      :       :       : type is SA-8A squad.
#
# set-up      :       :       : creating ground unit SA-8B.
# set-up      :       :       : type is SA-8B squad.
#
# set-up      :       :       : creating ground unit SA-9A.
# set-up      :       :       : type is SA-9A squad.
#
# set-up      :       :       : creating ground unit SA-9B.
# set-up      :       :       : type is SA-9B squad.
#
# set-up      :       :       : creating ground unit SA-11.
# set-up      :       :       : type is SA-11 squad.
#
# set-up      :       :       : creating ground unit SA-13.
# set-up      :       :       : type is SA-13 squad.
#
# set-up      :       :       : creating ground unit SA-14 .
# set-up      :       :       : type is SA-14 section.
#
# set-up      :       :       : creating ground unit M48.
# set-up      :       :       : type is M48 squad.
#
# set-up      :       :       : creating ground unit I-HAWK  .
# set-up      :       :       : type is I-HAWK platoon.
#
# set-up      :       :       : creating ground unit MIM-104A   .
# set-up      :       :       : type is MIM-104A battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit SA-2B
#   battery.
# set-up      :       :       : type is SA-2B battery.
#
# set-up      :       :       : creating ground unit SA-2C
#   battery.
# set-up      :       :       : type is SA-2C battery.
#
# set-up      :       :       : creating ground unit SA-2E
#   battery.
# set-up      :       :       : type is SA-2E battery.
#
# set-up      :       :       : creating ground unit SA-2F
#   battery.
# set-up      :       :       : type is SA-2F battery.
#
# set-up      :       :       : creating ground unit SA-3B
#   battery.
# set-up      :       :       : type is SA-3B battery.
#
# set-up      :       :       : creating ground unit mobile
#   SA-3B
#   battery.
# set-up      :       :       : type is mobile SA-3B battery.
#
# set-up      :       :       : creating ground unit SA-4A
#   battery.
# set-up      :       :       : type is SA-4A battery.
#
# set-up      :       :       : creating ground unit SA-4B
#   battery.
# set-up      :       :       : type is SA-4B battery.
#
# set-up      :       :       : creating ground unit SA-6A
#   battery.
# set-up      :       :       : type is SA-6A battery.
#
# set-up      :       :       : creating ground unit SA-6B
#   battery.
# set-up      :       :       : type is SA-6B battery.
#
# set-up      :       :       : creating ground unit SA-7A
#   section.
# set-up      :       :       : type is SA-7A section.
#
# set-up      :       :       : creating ground unit SA-7B
#   section.
# set-up      :       :       : type is SA-7B section.
#
# set-up      :       :       : creating ground unit SA-8A
#   squad.
# set-up      :       :       : type is SA-8A squad.
#
# set-up      :       :       : creating ground unit SA-8B
#   squad.
# set-up      :       :       : type is SA-8B squad.
#
# set-up      :       :       : creating ground unit SA-9A
#   squad.
# set-up      :       :       : type is SA-9A squad.
#
# set-up      :       :       : creating ground unit SA-9B
#   squad.
# set-up      :       :       : type is SA-9B squad.
#
# set-up      :       :       : creating ground unit SA-11
#   squad.
# set-up      :       :       : type is SA-11 squad.
#
# set-up      :       :       : creating ground unit SA-13
#   squad.
# set-up      :       :       : type is SA-13 squad.
#
# set-up      :       :       : creating ground unit SA-14
#   section.
# set-up      :       :       : type is SA-14 section.
#
# set-up      :       :       : creating ground unit M48
#   squad.
# set-up      :       :       : type is M48 squad.
#
# set-up      :       :       : creating ground unit I-HAWK
#   platoon.
# set-up      :       :       : type is I-HAWK platoon.
#
# set-up      :       :       : creating ground unit MIM-104A
#   battery.
# set-up      :       :       : type is MIM-104A battery.

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "locomotive",
        "railcar",
        "POL",
        "small building",
        "large building",
        "factory",
        "power station",
        "bunker entrance",
        "hanger",
        "shelter",
        "tower",
        "transport airplane",
        "fighter airplane",
        "helicopter",
        "barge",
        "junk",
        "pontoon bridge",
    ]:
        if s != "":
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(name, hexcode, s, color="lightgreen", counter=counter, identified=True)
        if y == 6:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=13.5, ymin=18.5, ymax=23.5)

# !mv map-00.png figure-ground-targets.png
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit locomotive.
# set-up      :       :       : type is locomotive.
#
# set-up      :       :       : creating ground unit railcar.
# set-up      :       :       : type is railcar.
#
# set-up      :       :       : creating ground unit POL.
# set-up      :       :       : type is POL.
#
# set-up      :       :       : creating ground unit small building.
# set-up      :       :       : type is small building.
#
# set-up      :       :       : creating ground unit large building.
# set-up      :       :       : type is large building.
#
# set-up      :       :       : creating ground unit factory.
# set-up      :       :       : type is factory.
#
# set-up      :       :       : creating ground unit power station.
# set-up      :       :       : type is power station.
#
# set-up      :       :       : creating ground unit bunker entrance.
# set-up      :       :       : type is bunker entrance.
#
# set-up      :       :       : creating ground unit hanger.
# set-up      :       :       : type is hanger.
#
# set-up      :       :       : creating ground unit shelter.
# set-up      :       :       : type is shelter.
#
# set-up      :       :       : creating ground unit tower.
# set-up      :       :       : type is tower.
#
# set-up      :       :       : creating ground unit transport airplane.
# set-up      :       :       : type is transport airplane.
#
# set-up      :       :       : creating ground unit fighter airplane.
# set-up      :       :       : type is fighter airplane.
#
# set-up      :       :       : creating ground unit helicopter.
# set-up      :       :       : type is helicopter.
#
# set-up      :       :       : creating ground unit barge.
# set-up      :       :       : type is barge.
#
# set-up      :       :       : creating ground unit junk.
# set-up      :       :       : type is junk.
#
# set-up      :       :       : creating ground unit pontoon bridge.
# set-up      :       :       : type is pontoon bridge.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit locomotive.
# set-up      :       :       : type is locomotive.
#
# set-up      :       :       : creating ground unit railcar.
# set-up      :       :       : type is railcar.
#
# set-up      :       :       : creating ground unit POL.
# set-up      :       :       : type is POL.
#
# set-up      :       :       : creating ground unit small
#   building.
# set-up      :       :       : type is small building.
#
# set-up      :       :       : creating ground unit large
#   building.
# set-up      :       :       : type is large building.
#
# set-up      :       :       : creating ground unit factory.
# set-up      :       :       : type is factory.
#
# set-up      :       :       : creating ground unit power
#   station.
# set-up      :       :       : type is power station.
#
# set-up      :       :       : creating ground unit bunker
#   entrance.
# set-up      :       :       : type is bunker entrance.
#
# set-up      :       :       : creating ground unit hanger.
# set-up      :       :       : type is hanger.
#
# set-up      :       :       : creating ground unit shelter.
# set-up      :       :       : type is shelter.
#
# set-up      :       :       : creating ground unit tower.
# set-up      :       :       : type is tower.
#
# set-up      :       :       : creating ground unit transport
#   airplane.
# set-up      :       :       : type is transport airplane.
#
# set-up      :       :       : creating ground unit fighter
#   airplane.
# set-up      :       :       : type is fighter airplane.
#
# set-up      :       :       : creating ground unit helicopter.
# set-up      :       :       : type is helicopter.
#
# set-up      :       :       : creating ground unit barge.
# set-up      :       :       : type is barge.
#
# set-up      :       :       : creating ground unit junk.
# set-up      :       :       : type is junk.
#
# set-up      :       :       : creating ground unit pontoon
#   bridge.
# set-up      :       :       : type is pontoon bridge.

# %%
startgamesetup(
    None,
    sheets=[["F"]],
    style="temperateplain",
    writelogfiles=False,
    dotsperhex=300,
    levelincrement=0,
)

# endgamesetup()
# startgameturn()

drawmap(zoom=False, xmin=0.5, xmax=8.5, ymin=17, ymax=24)
import glass.draw

for x, y, label in [
    [1, 23.5, "G/U"],
    [1, 22.5, "G/U"],
    [1, 21.5, "G/U"],
    [1, 20.5, "P/G/U"],
    [1, 19.5, "G/U"],
    [1, 18.5, "G/U"],
    [1, 17.5, "G/U"],
    [2, 23.0, "G/U"],
    [2, 22.0, "G/U"],
    [2, 21.0, "P/G/U"],
    [2, 20.0, "G/U"],
    [2, 19.0, "G/U"],
    [2, 18.0, ""],
    [3, 23.5, "G/U"],
    [3, 22.5, "G/U"],
    [3, 21.5, "P/G/U"],
    [3, 20.5, "G/U"],
    [3, 19.5, "G/U"],
    [3, 18.5, "G/U"],
    [3, 17.5, "G/U"],
    [4, 23.0, "G/U"],
    [4, 22.0, "P/G/U"],
    [4, 21.0, "G/U"],
    [4, 20.0, "U"],
    [4, 19.0, "G/U"],
    [4, 18.0, "G/U"],
    [5, 23.5, "P/G/U"],
    [5, 22.5, "P/G/U"],
    [5, 21.5, "G/U"],
    [5, 20.5, "G/U"],
    [5, 19.5, "G/U"],
    [5, 18.5, "G/U"],
    [5, 17.5, "G/U"],
    [6, 23.0, "P/G/U"],
    [6, 22.0, "P/G/U"],
    [6, 21.0, "G/U"],
    [6, 20.0, "G/U"],
    [6, 19.0, "G/U"],
    [6, 18.0, "G/U"],
    [7, 23.5, "G/U"],
    [7, 22.5, "P/G/U"],
    [7, 21.5, "P/G/U"],
    [7, 20.5, "P/G/U"],
    [7, 19.5, "G/U"],
    [7, 18.5, "G/U"],
    [7, 17.5, "G/U"],
    [8, 23.0, "G/U"],
    [8, 22.0, "P/G/U"],
    [8, 21.0, "P/G/U"],
    [8, 20.0, "P/G/U"],
    [8, 19.0, "G/U"],
    [8, 18.0, "G/U"],
]:
    if "P" in label:
        color = "natogreen"
    elif "G" in label:
        color = "natoyellow"
    elif "U" in label:
        color = "natored"
    if label != "":
        glass.draw._drawdotincanvas(
            *glass.draw._tocanvasxy(x, y), 0.1, fillcolor=color, linewidth="thin"
        )

glass.draw.writecanvastofile("figure-mobility.png")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['F']].
# set-up      : north is up.
# set-up      : map option style is 'temperateplain'.
# set-up      : map option dotsperhex is 300.
# set-up      : map option levelincrement is 0.
