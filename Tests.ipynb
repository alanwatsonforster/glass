# %%
import sys
sys.path.append('/Users/alan/GitHub/Home/glass/src/')
from glass import *

# %%
import glass.log
glass.log.setwritefiles(False)
import glass.map
glass.map.setwritefiles(False)

# %%
import glass.tests.a0
import glass.tests.a1
import glass.tests.a2
import glass.tests.a3
import glass.tests.a4
import glass.tests.a5
import glass.tests.c0
import glass.tests.c1
import glass.tests.c2
import glass.tests.c3
import glass.tests.d0
import glass.tests.d1
import glass.tests.d2
import glass.tests.d3
import glass.tests.d4
import glass.tests.d5
import glass.tests.e0
import glass.tests.e1
import glass.tests.e2
import glass.tests.e3
import glass.tests.e4
import glass.tests.e5
import glass.tests.e7
import glass.tests.e6
import glass.tests.f0
import glass.tests.f1
import glass.tests.f2
import glass.tests.f3
import glass.tests.g0
import glass.tests.g1
import glass.tests.g2
import glass.tests.g3
import glass.tests.g4
import glass.tests.g5
import glass.tests.g6
import glass.tests.h0
import glass.tests.i0
import glass.tests.i1
import glass.tests.j0
import glass.tests.j1
import glass.tests.j2
import glass.tests.j3
import glass.tests.j4
import glass.tests.j5
import glass.tests.j6
import glass.tests.k0
import glass.tests.k1
import glass.tests.l0
import glass.tests.m0
import glass.tests.n0
import glass.tests.n1
import glass.tests.n2
import glass.tests.n3
import glass.tests.o0
import glass.tests.o1
import glass.tests.o2
import glass.tests.o3
import glass.tests.o4
import glass.tests.o5
import glass.tests.o6

print("finished running all tests.")
# Out:
# running tests in file a0.py: aircraft data.
# running tests in file a1.py: aircraft creation.
# running tests in file a2.py: math.
# running tests in file a3.py: azimuths.
# running tests in file a4.py: distances.
# running tests in file a5.py: maps.
# running tests in file c0.py: speed.
# running tests in file c1.py: propeller power.
# running tests in file c2.py: flamed-out engines.
# running tests in file c3.py: speed brakes.
# running tests in file d0.py: turns.
# running tests in file d1.py: slatted wings.
# running tests in file d2.py: banking.
# running tests in file d3.py: LBR/HBR aircraft.
# running tests in file d4.py: gloc.
# running tests in file d5.py: variable-geometry aircraft.
# running tests in file e0.py: initial HFPs.
# running tests in file e1.py: climbs.
# running tests in file e2.py: dives.
# running tests in file e3.py: loss of thrust with altitude.
# running tests in file e4.py: HPR aircraft.
# running tests in file e5.py: collision with terrain.
# running tests in file e7.py: terrain-following flight.
# running tests in file e6.py: ABSF aircraft.
# running tests in file f0.py: departed flight.
# running tests in file f1.py: stalled flight.
# running tests in file f2.py: special flight.
# running tests in file f3.py: special flight.
# running tests in file g0.py: slides.
# running tests in file g1.py: displacement rolls.
# running tests in file g2.py: lag rolls.
# running tests in file g3.py: vertical rolls.
# running tests in file g4.py: HRD.
# running tests in file g5.py: NRM aircraft.
# running tests in file g6.py: attacks after rolls.
# running tests in file h0.py: stores.
# running tests in file i0.py: close formations.
# running tests in file i1.py: close formation flying limits.
# running tests in file j0.py: angle-off.
# running tests in file j1.py: gun attack range.
# running tests in file j2.py: rocket attack range.
# running tests in file j3.py: articulated gun attack range.
# running tests in file j4.py: air-to-air attacks.
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A1'], ['A2']].
# set-up      : north is up.
#
# set-up      :       :       : creating aircraft A0.
# set-up      : A0    :       : force         is AF.
# set-up      : A0    :       : type          is F-80C.
# set-up      : A0    :       : position      is A1-1815       N    20.
# set-up      : A0    :       : speed         is 4.0.
# set-up      : A0    :       : configuration is CL.
#
# set-up      :       :       : creating aircraft A1.
# set-up      : A1    :       : force         is AF.
# set-up      : A1    :       : type          is F-80C.
# set-up      : A1    :       : position      is A1-1814       N    20.
# set-up      : A1    :       : speed         is 4.0.
# set-up      : A1    :       : configuration is CL.
#
# set-up      :       :       : creating aircraft A2.
# set-up      : A2    :       : force         is AF.
# set-up      : A2    :       : type          is F-80C.
# set-up      : A2    :       : position      is A1-2212       WNW  20.
# set-up      : A2    :       : speed         is 4.0.
# set-up      : A2    :       : configuration is CL.
#
# set-up      :       :       : creating aircraft A3.
# set-up      : A3    :       : force         is AF.
# set-up      : A3    :       : type          is F-80C.
# set-up      : A3    :       : position      is A1-2210       W    20.
# set-up      : A3    :       : speed         is 4.0.
# set-up      : A3    :       : configuration is CL.
#
# set-up      :       :       : creating aircraft A4.
# set-up      : A4    :       : force         is AF.
# set-up      : A4    :       : type          is F-80C.
# set-up      : A4    :       : position      is A1-1810       N    20.
# set-up      : A4    :       : speed         is 4.0.
# set-up      : A4    :       : configuration is CL.
#
# set-up      : end of game set-up.
#
# game turn  1: start of game turn.
# game turn  1: initial aircraft positions, speeds, maneuvers, and previous flight types:
# game turn  1: A0    : A1-1815       N    20   4.0             LVL
# game turn  1: A1    : A1-1814       N    20   4.0             LVL
# game turn  1: A2    : A1-2212       WNW  20   4.0             LVL
# game turn  1: A3    : A1-2210       W    20   4.0             LVL
# game turn  1: A4    : A1-1810       N    20   4.0             LVL
#
# game turn  1: A1    : start : flight type      is LVL.
# game turn  1: A1    : start : altitude band    is MH.
# game turn  1: A1    :       :                                  : speed of sound is 7.0.
# game turn  1: A1    : start : speed            is 4.0.
# game turn  1: A1    :       :                                  : speed is subsonic and below low transsonic.
# game turn  1: A1    : start : configuration    is CL.
# game turn  1: A1    : start : damage           is none.
# game turn  1: A1    : start : power setting    is M.
# game turn  1: A1    :       :                                  : M power (+1.0 AP).
# game turn  1: A1    :       :                                  : minumum speed is 2.0.
# game turn  1: A1    :       :                                  : is carrying +0.00 APs.
# game turn  1: A1    :       :                                  : turn rate is limited to BT.
# game turn  1: A1    : start : is carrying 0.0 FPs.
# game turn  1: A1    : start : has 4 FPs.
# game turn  1: A1    :       :                                  : all FPs must be HFPs.
# game turn  1: A1    : start : A1-1814       N    20
# game turn  1: A1    : FP 1  : H
# game turn  1: A1    :       : A1-1813       N    20
# game turn  1: A1    : FP 2  : H
# game turn  1: A1    :       : A1-1812       N    20
# game turn  1: A1    : FP 3  : H
# game turn  1: A1    :       : A1-1811       N    20
# game turn  1: A1    : FP 4  : H
# game turn  1: A1    : end   : A1-1810       N    20
# game turn  1: A1    :       :                                  : used 4 HFPs and 0 VFPs.
# game turn  1: A1    :       :                                  : flight slope is +0/4 = +0.00.
# game turn  1: A1    : end   : will carry 0.0 FPs.
# game turn  1: A1    :       :                                  : power           APs = +1.00.
# game turn  1: A1    :       :                                  : speed           APs = +0.00.
# game turn  1: A1    :       :                                  : altitude        APs = +0.00.
# game turn  1: A1    :       :                                  : turns           APs = +0.00.
# game turn  1: A1    :       :                                  : other maneuvers APs = +0.00.
# game turn  1: A1    :       :                                  : speedbrakes     APs = +0.00.
# game turn  1: A1    :       :                                  : carry           APs = +0.00.
# game turn  1: A1    :       :                                  : total           APs = +1.00.
# game turn  1: A1    : end   : speed will be 4.0.
# game turn  1: A1    :       :                                  : speed will be subsonic.
# game turn  1: A1    : end   : will carry +1.00 APs.
#
# game turn  1: A0    : start : flight type      is LVL.
# game turn  1: A0    : start : altitude band    is MH.
# game turn  1: A0    :       :                                  : speed of sound is 7.0.
# game turn  1: A0    : start : speed            is 4.0.
# game turn  1: A0    :       :                                  : speed is subsonic and below low transsonic.
# game turn  1: A0    : start : configuration    is CL.
# game turn  1: A0    : start : damage           is none.
# game turn  1: A0    : start : power setting    is M.
# game turn  1: A0    :       :                                  : M power (+1.0 AP).
# game turn  1: A0    :       :                                  : minumum speed is 2.0.
# game turn  1: A0    :       :                                  : is carrying +0.00 APs.
# game turn  1: A0    :       :                                  : turn rate is limited to BT.
# game turn  1: A0    : start : is carrying 0.0 FPs.
# game turn  1: A0    : start : has 4 FPs.
# game turn  1: A0    :       :                                  : all FPs must be HFPs.
# game turn  1: A0    : start : A1-1815       N    20
#
# game turn  1: A0    :       :                                  : started tracking A1.
#
# game turn  1: A0    : FP 1  : H
# game turn  1: A0    :       : A1-1814       N    20
# game turn  1: A0    : FP 2  : H
# game turn  1: A0    :       : A1-1813       N    20
# game turn  1: A0    : FP 3  : H
# game turn  1: A0    :       : A1-1812       N    20
# game turn  1: A0    : FP 4  : H
# game turn  1: A0    : end   : A1-1811       N    20
# game turn  1: A0    :       :                                  : used 4 HFPs and 0 VFPs.
# game turn  1: A0    :       :                                  : flight slope is +0/4 = +0.00.
# game turn  1: A0    : end   : will carry 0.0 FPs.
# game turn  1: A0    :       :                                  : power           APs = +1.00.
# game turn  1: A0    :       :                                  : speed           APs = +0.00.
# game turn  1: A0    :       :                                  : altitude        APs = +0.00.
# game turn  1: A0    :       :                                  : turns           APs = +0.00.
# game turn  1: A0    :       :                                  : other maneuvers APs = +0.00.
# game turn  1: A0    :       :                                  : speedbrakes     APs = +0.00.
# game turn  1: A0    :       :                                  : carry           APs = +0.00.
# game turn  1: A0    :       :                                  : total           APs = +1.00.
# game turn  1: A0    : end   : speed will be 4.0.
# game turn  1: A0    :       :                                  : speed will be subsonic.
# game turn  1: A0    : end   : will carry +1.00 APs.
#
# game turn  1: A0    :       :                                  : gun air-to-air attack on A1.
# game turn  1: A0    :       :                                  : range is 1.
# game turn  1: A0    :       :                                  : angle-off-tail is 0 line.
# game turn  1: A0    :       :                                  : tracking for 4 FPs.
# game turn  1: A0    :       :                                  : attacker does not have radar ranging.
# game turn  1: A0    :       :                                  : no applicable turn rate.
# game turn  1: A0    :       :                                  : target size        modifier is +0.
# game turn  1: A0    :       :                                  : angle-off-tail     modifier is -2.
# game turn  1: A0    :       :                                  : tracking           modifier is -2.
# game turn  1: A0    :       :                                  : total to-hit       modifier is -4.
# game turn  1: A0    :       :                                  : to-hit roll is 3.
# game turn  1: A0    :       :                                  : damage rating is 4 + +0 = 4.
# game turn  1: A0    :       :                                  : target vulnerability is +1.
# game turn  1: A0    :       : hits but inflicts no damage.
# game turn  1: A0    :       :                                  : 7.0 gun ammunition remain.
#
# game turn  1: start of game turn.
# game turn  1: initial aircraft positions, speeds, maneuvers, and previous flight types:
# game turn  1: A0    : A1-1815       N    20   4.0             LVL
# game turn  1: A1    : A1-1814       N    20   4.0             LVL
# game turn  1: A2    : A1-2212       WNW  20   4.0             LVL
# game turn  1: A3    : A1-2210       W    20   4.0             LVL
# game turn  1: A4    : A1-1810       N    20   4.0             LVL
#
# game turn  1: A2    : start : flight type      is LVL.
# game turn  1: A2    : start : altitude band    is MH.
# game turn  1: A2    :       :                                  : speed of sound is 7.0.
# game turn  1: A2    : start : speed            is 4.0.
# game turn  1: A2    :       :                                  : speed is subsonic and below low transsonic.
# game turn  1: A2    : start : configuration    is CL.
# game turn  1: A2    : start : damage           is none.
# game turn  1: A2    : start : power setting    is M.
# game turn  1: A2    :       :                                  : M power (+1.0 AP).
# game turn  1: A2    :       :                                  : minumum speed is 2.0.
# game turn  1: A2    :       :                                  : is carrying +0.00 APs.
# game turn  1: A2    :       :                                  : turn rate is limited to BT.
# game turn  1: A2    : start : is carrying 0.0 FPs.
# game turn  1: A2    : start : has 4 FPs.
# game turn  1: A2    :       :                                  : all FPs must be HFPs.
# game turn  1: A2    : start : A1-2212       WNW  20
# game turn  1: A2    : FP 1  : H
# game turn  1: A2    :       : A1-2111       WNW  20
# game turn  1: A2    : FP 2  : H
# game turn  1: A2    :       : A1-2011       WNW  20
# game turn  1: A2    : FP 3  : H
# game turn  1: A2    :       : A1-1910       WNW  20
# game turn  1: A2    : FP 4  : H
# game turn  1: A2    : end   : A1-1810       WNW  20
# game turn  1: A2    :       :                                  : used 4 HFPs and 0 VFPs.
# game turn  1: A2    :       :                                  : flight slope is +0/4 = +0.00.
# game turn  1: A2    : end   : will carry 0.0 FPs.
# game turn  1: A2    :       :                                  : power           APs = +1.00.
# game turn  1: A2    :       :                                  : speed           APs = +0.00.
# game turn  1: A2    :       :                                  : altitude        APs = +0.00.
# game turn  1: A2    :       :                                  : turns           APs = +0.00.
# game turn  1: A2    :       :                                  : other maneuvers APs = +0.00.
# game turn  1: A2    :       :                                  : speedbrakes     APs = +0.00.
# game turn  1: A2    :       :                                  : carry           APs = +0.00.
# game turn  1: A2    :       :                                  : total           APs = +1.00.
# game turn  1: A2    : end   : speed will be 4.0.
# game turn  1: A2    :       :                                  : speed will be subsonic.
# game turn  1: A2    : end   : will carry +1.00 APs.
#
# game turn  1: A0    : start : flight type      is LVL.
# game turn  1: A0    : start : altitude band    is MH.
# game turn  1: A0    :       :                                  : speed of sound is 7.0.
# game turn  1: A0    : start : speed            is 4.0.
# game turn  1: A0    :       :                                  : speed is subsonic and below low transsonic.
# game turn  1: A0    : start : configuration    is CL.
# game turn  1: A0    : start : damage           is none.
# game turn  1: A0    : start : power setting    is M.
# game turn  1: A0    :       :                                  : M power (+1.0 AP).
# game turn  1: A0    :       :                                  : minumum speed is 2.0.
# game turn  1: A0    :       :                                  : is carrying +0.00 APs.
# game turn  1: A0    :       :                                  : turn rate is limited to BT.
# game turn  1: A0    : start : is carrying 0.0 FPs.
# game turn  1: A0    : start : has 4 FPs.
# game turn  1: A0    :       :                                  : all FPs must be HFPs.
# game turn  1: A0    : start : A1-1815       N    20
#
# game turn  1: A0    :       :                                  : started tracking A2.
#
# game turn  1: A0    : FP 1  : H
# game turn  1: A0    :       : A1-1814       N    20
# game turn  1: A0    : FP 2  : H
# game turn  1: A0    :       : A1-1813       N    20
# game turn  1: A0    : FP 3  : H
# game turn  1: A0    :       : A1-1812       N    20
# game turn  1: A0    : FP 4  : H
# game turn  1: A0    : end   : A1-1811       N    20
# game turn  1: A0    :       :                                  : used 4 HFPs and 0 VFPs.
# game turn  1: A0    :       :                                  : flight slope is +0/4 = +0.00.
# game turn  1: A0    : end   : will carry 0.0 FPs.
# game turn  1: A0    :       :                                  : power           APs = +1.00.
# game turn  1: A0    :       :                                  : speed           APs = +0.00.
# game turn  1: A0    :       :                                  : altitude        APs = +0.00.
# game turn  1: A0    :       :                                  : turns           APs = +0.00.
# game turn  1: A0    :       :                                  : other maneuvers APs = +0.00.
# game turn  1: A0    :       :                                  : speedbrakes     APs = +0.00.
# game turn  1: A0    :       :                                  : carry           APs = +0.00.
# game turn  1: A0    :       :                                  : total           APs = +1.00.
# game turn  1: A0    : end   : speed will be 4.0.
# game turn  1: A0    :       :                                  : speed will be subsonic.
# game turn  1: A0    : end   : will carry +1.00 APs.
#
# game turn  1: A0    :       :                                  : gun air-to-air attack on A2.
# game turn  1: A0    :       :                                  : range is 1.
# game turn  1: A0    :       :                                  : angle-off-tail is 60 arc.
# game turn  1: A0    :       :                                  : tracking for 4 FPs.
# game turn  1: A0    :       :                                  : attacker does not have radar ranging.
# game turn  1: A0    :       :                                  : no applicable turn rate.
# game turn  1: A0    :       :                                  : target size        modifier is +0.
# game turn  1: A0    :       :                                  : angle-off-tail     modifier is +2.
# game turn  1: A0    :       :                                  : tracking           modifier is -2.
# game turn  1: A0    :       :                                  : total to-hit       modifier is +0.
# game turn  1: A0    :       :                                  : to-hit roll is 3.
# game turn  1: A0    :       :                                  : damage rating is 4 + +0 = 4.
# game turn  1: A0    :       :                                  : target vulnerability is +1.
# game turn  1: A0    :       : hits but inflicts no damage.
# game turn  1: A0    :       :                                  : 7.0 gun ammunition remain.
#
# game turn  1: start of game turn.
# game turn  1: initial aircraft positions, speeds, maneuvers, and previous flight types:
# game turn  1: A0    : A1-1815       N    20   4.0             LVL
# game turn  1: A1    : A1-1814       N    20   4.0             LVL
# game turn  1: A2    : A1-2212       WNW  20   4.0             LVL
# game turn  1: A3    : A1-2210       W    20   4.0             LVL
# game turn  1: A4    : A1-1810       N    20   4.0             LVL
#
# game turn  1: A3    : start : flight type      is LVL.
# game turn  1: A3    : start : altitude band    is MH.
# game turn  1: A3    :       :                                  : speed of sound is 7.0.
# game turn  1: A3    : start : speed            is 4.0.
# game turn  1: A3    :       :                                  : speed is subsonic and below low transsonic.
# game turn  1: A3    : start : configuration    is CL.
# game turn  1: A3    : start : damage           is none.
# game turn  1: A3    : start : power setting    is M.
# game turn  1: A3    :       :                                  : M power (+1.0 AP).
# game turn  1: A3    :       :                                  : minumum speed is 2.0.
# game turn  1: A3    :       :                                  : is carrying +0.00 APs.
# game turn  1: A3    :       :                                  : turn rate is limited to BT.
# game turn  1: A3    : start : is carrying 0.0 FPs.
# game turn  1: A3    : start : has 4 FPs.
# game turn  1: A3    :       :                                  : all FPs must be HFPs.
# game turn  1: A3    : start : A1-2210       W    20
# game turn  1: A3    : FP 1  : H
# game turn  1: A3    :       : A1-2109/2110  W    20
# game turn  1: A3    : FP 2  : H
# game turn  1: A3    :       : A1-2010       W    20
# game turn  1: A3    : FP 3  : H
# game turn  1: A3    :       : A1-1909/1910  W    20
# game turn  1: A3    : FP 4  : H
# game turn  1: A3    : end   : A1-1810       W    20
# game turn  1: A3    :       :                                  : used 4 HFPs and 0 VFPs.
# game turn  1: A3    :       :                                  : flight slope is +0/4 = +0.00.
# game turn  1: A3    : end   : will carry 0.0 FPs.
# game turn  1: A3    :       :                                  : power           APs = +1.00.
# game turn  1: A3    :       :                                  : speed           APs = +0.00.
# game turn  1: A3    :       :                                  : altitude        APs = +0.00.
# game turn  1: A3    :       :                                  : turns           APs = +0.00.
# game turn  1: A3    :       :                                  : other maneuvers APs = +0.00.
# game turn  1: A3    :       :                                  : speedbrakes     APs = +0.00.
# game turn  1: A3    :       :                                  : carry           APs = +0.00.
# game turn  1: A3    :       :                                  : total           APs = +1.00.
# game turn  1: A3    : end   : speed will be 4.0.
# game turn  1: A3    :       :                                  : speed will be subsonic.
# game turn  1: A3    : end   : will carry +1.00 APs.
#
# game turn  1: A0    : start : flight type      is LVL.
# game turn  1: A0    : start : altitude band    is MH.
# game turn  1: A0    :       :                                  : speed of sound is 7.0.
# game turn  1: A0    : start : speed            is 4.0.
# game turn  1: A0    :       :                                  : speed is subsonic and below low transsonic.
# game turn  1: A0    : start : configuration    is CL.
# game turn  1: A0    : start : damage           is none.
# game turn  1: A0    : start : power setting    is M.
# game turn  1: A0    :       :                                  : M power (+1.0 AP).
# game turn  1: A0    :       :                                  : minumum speed is 2.0.
# game turn  1: A0    :       :                                  : is carrying +0.00 APs.
# game turn  1: A0    :       :                                  : turn rate is limited to BT.
# game turn  1: A0    : start : is carrying 0.0 FPs.
# game turn  1: A0    : start : has 4 FPs.
# game turn  1: A0    :       :                                  : all FPs must be HFPs.
# game turn  1: A0    : start : A1-1815       N    20
#
#
# === ERROR: attempt to start tracking while A0 is not in its 60- arc of A3. ===
#
#
# game turn  1: start of game turn.
# game turn  1: initial aircraft positions, speeds, maneuvers, and previous flight types:
# game turn  1: A0    : A1-1815       N    20   4.0             LVL
# game turn  1: A1    : A1-1814       N    20   4.0             LVL
# game turn  1: A2    : A1-2212       WNW  20   4.0             LVL
# game turn  1: A3    : A1-2210       W    20   4.0             LVL
# game turn  1: A4    : A1-1810       N    20   4.0             LVL
#
# game turn  1: A4    : start : flight type      is LVL.
# game turn  1: A4    : start : altitude band    is MH.
# game turn  1: A4    :       :                                  : speed of sound is 7.0.
# game turn  1: A4    : start : speed            is 4.0.
# game turn  1: A4    :       :                                  : speed is subsonic and below low transsonic.
# game turn  1: A4    : start : configuration    is CL.
# game turn  1: A4    : start : damage           is none.
# game turn  1: A4    : start : power setting    is M.
# game turn  1: A4    :       :                                  : M power (+1.0 AP).
# game turn  1: A4    :       :                                  : minumum speed is 2.0.
# game turn  1: A4    :       :                                  : is carrying +0.00 APs.
# game turn  1: A4    :       :                                  : turn rate is limited to BT.
# game turn  1: A4    : start : is carrying 0.0 FPs.
# game turn  1: A4    : start : has 4 FPs.
# game turn  1: A4    :       :                                  : all FPs must be HFPs.
# game turn  1: A4    : start : A1-1810       N    20
# game turn  1: A4    : FP 1  : H
# game turn  1: A4    :       : A1-1809       N    20
# game turn  1: A4    : FP 2  : H
# game turn  1: A4    :       : A1-1808       N    20
# game turn  1: A4    : FP 3  : H
# game turn  1: A4    :       : A1-1807       N    20
# game turn  1: A4    : FP 4  : H
# game turn  1: A4    : end   : A1-1806       N    20
# game turn  1: A4    :       :                                  : used 4 HFPs and 0 VFPs.
# game turn  1: A4    :       :                                  : flight slope is +0/4 = +0.00.
# game turn  1: A4    : end   : will carry 0.0 FPs.
# game turn  1: A4    :       :                                  : power           APs = +1.00.
# game turn  1: A4    :       :                                  : speed           APs = +0.00.
# game turn  1: A4    :       :                                  : altitude        APs = +0.00.
# game turn  1: A4    :       :                                  : turns           APs = +0.00.
# game turn  1: A4    :       :                                  : other maneuvers APs = +0.00.
# game turn  1: A4    :       :                                  : speedbrakes     APs = +0.00.
# game turn  1: A4    :       :                                  : carry           APs = +0.00.
# game turn  1: A4    :       :                                  : total           APs = +1.00.
# game turn  1: A4    : end   : speed will be 4.0.
# game turn  1: A4    :       :                                  : speed will be subsonic.
# game turn  1: A4    : end   : will carry +1.00 APs.
#
# game turn  1: A0    : start : flight type      is LVL.
# game turn  1: A0    : start : altitude band    is MH.
# game turn  1: A0    :       :                                  : speed of sound is 7.0.
# game turn  1: A0    : start : speed            is 4.0.
# game turn  1: A0    :       :                                  : speed is subsonic and below low transsonic.
# game turn  1: A0    : start : configuration    is CL.
# game turn  1: A0    : start : damage           is none.
# game turn  1: A0    : start : power setting    is M.
# game turn  1: A0    :       :                                  : M power (+1.0 AP).
# game turn  1: A0    :       :                                  : minumum speed is 2.0.
# game turn  1: A0    :       :                                  : is carrying +0.00 APs.
# game turn  1: A0    :       :                                  : turn rate is limited to BT.
# game turn  1: A0    : start : is carrying 0.0 FPs.
# game turn  1: A0    : start : has 4 FPs.
# game turn  1: A0    :       :                                  : all FPs must be HFPs.
# game turn  1: A0    : start : A1-1815       N    20
#
#
# === ERROR: attempt to start tracking while A4 is more than 6 hexes from A0. ===
#
#
# game turn  1: start of game turn.
# game turn  1: initial aircraft positions, speeds, maneuvers, and previous flight types:
# game turn  1: A0    : A1-1815       N    20   4.0             LVL
# game turn  1: A1    : A1-1814       N    20   4.0             LVL
# game turn  1: A2    : A1-2212       WNW  20   4.0             LVL
# game turn  1: A3    : A1-2210       W    20   4.0             LVL
# game turn  1: A4    : A1-1810       N    20   4.0             LVL
#
# game turn  1: A1    : start : flight type      is LVL.
# game turn  1: A1    : start : altitude band    is MH.
# game turn  1: A1    :       :                                  : speed of sound is 7.0.
# game turn  1: A1    : start : speed            is 4.0.
# game turn  1: A1    :       :                                  : speed is subsonic and below low transsonic.
# game turn  1: A1    : start : configuration    is CL.
# game turn  1: A1    : start : damage           is none.
# game turn  1: A1    : start : power setting    is M.
# game turn  1: A1    :       :                                  : M power (+1.0 AP).
# game turn  1: A1    :       :                                  : minumum speed is 2.0.
# game turn  1: A1    :       :                                  : is carrying +0.00 APs.
# game turn  1: A1    :       :                                  : turn rate is limited to BT.
# game turn  1: A1    : start : is carrying 0.0 FPs.
# game turn  1: A1    : start : has 4 FPs.
# game turn  1: A1    :       :                                  : all FPs must be HFPs.
# game turn  1: A1    : start : A1-1814       N    20
# game turn  1: A1    : FP 1  : H
# game turn  1: A1    :       : A1-1813       N    20
# game turn  1: A1    : FP 2  : H
# game turn  1: A1    :       : A1-1812       N    20
# game turn  1: A1    : FP 3  : H
# game turn  1: A1    :       : A1-1811       N    20
# game turn  1: A1    : FP 4  : H
# game turn  1: A1    : end   : A1-1810       N    20
# game turn  1: A1    :       :                                  : used 4 HFPs and 0 VFPs.
# game turn  1: A1    :       :                                  : flight slope is +0/4 = +0.00.
# game turn  1: A1    : end   : will carry 0.0 FPs.
# game turn  1: A1    :       :                                  : power           APs = +1.00.
# game turn  1: A1    :       :                                  : speed           APs = +0.00.
# game turn  1: A1    :       :                                  : altitude        APs = +0.00.
# game turn  1: A1    :       :                                  : turns           APs = +0.00.
# game turn  1: A1    :       :                                  : other maneuvers APs = +0.00.
# game turn  1: A1    :       :                                  : speedbrakes     APs = +0.00.
# game turn  1: A1    :       :                                  : carry           APs = +0.00.
# game turn  1: A1    :       :                                  : total           APs = +1.00.
# game turn  1: A1    : end   : speed will be 4.0.
# game turn  1: A1    :       :                                  : speed will be subsonic.
# game turn  1: A1    : end   : will carry +1.00 APs.
#
# game turn  1: A0    : start : flight type      is LVL.
# game turn  1: A0    : start : altitude band    is MH.
# game turn  1: A0    :       :                                  : speed of sound is 7.0.
# game turn  1: A0    : start : speed            is 4.0.
# game turn  1: A0    :       :                                  : speed is subsonic and below low transsonic.
# game turn  1: A0    : start : configuration    is CL.
# game turn  1: A0    : start : damage           is none.
# game turn  1: A0    : start : power setting    is M.
# game turn  1: A0    :       :                                  : M power (+1.0 AP).
# game turn  1: A0    :       :                                  : minumum speed is 2.0.
# game turn  1: A0    :       :                                  : is carrying +0.00 APs.
# game turn  1: A0    :       :                                  : turn rate is limited to BT.
# game turn  1: A0    : start : is carrying 0.0 FPs.
# game turn  1: A0    : start : has 4 FPs.
# game turn  1: A0    :       :                                  : all FPs must be HFPs.
# game turn  1: A0    : start : A1-1815       N    20
#
# game turn  1: A0    :       :                                  : started tracking A1.
#
# game turn  1: A0    : FP 1  : BTR/H/R
# game turn  1: A0    :       :                                  : declared BTR 0/1.
# game turn  1: A0    :       : A1-1814       NNE  20  BR
# game turn  1: A0    : FP 2  : H/WL
# game turn  1: A0    :       :                                  : stopped tracking as A1 is not in the limited arc of A0.
# game turn  1: A0    :       : A1-1813/1913  NNE  20
# game turn  1: A0    : FP 3  : BTL/H/L+
# game turn  1: A0    :       :                                  : declared BTL 0/1.
# game turn  1: A0    :       :                                  : declared BTL 0/1.
# game turn  1: A0    :       : A1-1912       N    20  BTL 0/1
# game turn  1: A0    : FP 4  : H/L
# game turn  1: A0    : end   : A1-1911       NNW  20  BL
# game turn  1: A0    :       :                                  : used 4 HFPs and 0 VFPs.
# game turn  1: A0    :       :                                  : flight slope is +0/4 = +0.00.
# game turn  1: A0    : end   : will carry 0.0 FPs.
# game turn  1: A0    :       :                                  : power           APs = +1.00.
# game turn  1: A0    :       :                                  : speed           APs = +0.00.
# game turn  1: A0    :       :                                  : altitude        APs = +0.00.
# game turn  1: A0    :       :                                  : turns           APs = -3.00.
# game turn  1: A0    :       :                                  : other maneuvers APs = +0.00.
# game turn  1: A0    :       :                                  : speedbrakes     APs = +0.00.
# game turn  1: A0    :       :                                  : carry           APs = +0.00.
# game turn  1: A0    :       :                                  : total           APs = -2.00.
# game turn  1: A0    : end   : speed will be 3.5.
# game turn  1: A0    :       :                                  : speed will be subsonic.
# game turn  1: A0    : end   : will carry -0.00 APs.
#
# game turn  1: A0    :       :                                  : gun air-to-air attack on A1.
# game turn  1: A0    :       :                                  : range is 2.
# game turn  1: A0    :       :                                  : angle-off-tail is 30 arc.
# game turn  1: A0    :       :                                  : tracking for 0 FPs.
# game turn  1: A0    :       :                                  : attacker does not have radar ranging.
# game turn  1: A0    :       :                                  : applicable turn rate is BT.
# game turn  1: A0    :       :                                  : target size        modifier is +0.
# game turn  1: A0    :       :                                  : angle-off-tail     modifier is +0.
# game turn  1: A0    :       :                                  : tracking           modifier is +0.
# game turn  1: A0    :       :                                  : attacker turn-rate modifier is +2.
# game turn  1: A0    :       :                                  : total to-hit       modifier is +2.
# game turn  1: A0    :       :                                  : to-hit roll is 0.
# game turn  1: A0    :       :                                  : damage rating is 4 + +0 = 4.
# game turn  1: A0    :       :                                  : target vulnerability is +1.
# game turn  1: A0    :       : hits but inflicts no damage.
# game turn  1: A0    :       :                                  : 7.0 gun ammunition remain.
#
# running tests in file j5.py: radar vertical limits.
# running tests in file j6.py: arcs.
# running tests in file k0.py: damage.
# running tests in file k1.py: damage effects.
# running tests in file l0.py: fuel.
# running tests in file m0.py: visual sighting.
# running tests in file n0.py: missile launches.
# running tests in file n1.py: missile speed.
# running tests in file n2.py: missile flight.
# running tests in file n3.py: missile attacks.
# running tests in file o0.py: ground unit creation.
# running tests in file o1.py: ground unit damage.
# running tests in file o2.py: ground unit barrage fire.
# running tests in file o3.py: ground unit plotted fire.
# running tests in file o4.py: ground unit aimed fire.
# running tests in file o5.py: ground unit movement.
# running tests in file o6.py: attacks on ground unit.
# finished running all tests.
